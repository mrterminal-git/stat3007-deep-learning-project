# %% [markdown]
# Import all the classes we need.

# %%
from PriceDataLoader import PriceDataLoader
from WeatherDataLoader import WeatherDataLoader
from models.CNN import *
from models.FFN import *
import torch
from models.CointegrationResidualGenerator import CointegrationResidualGenerator
from PortfolioOptimizer import PortfolioOptimizer
from Trainer import Trainer
from PortfolioOptimizer import PortfolioOptimizer
from DataPreparation import DataPreparation
import pandas as pd
from datetime import datetime, timedelta
import os

# %% [markdown]
# Set the device

# %%
device = torch.device("cuda" if torch.cuda.is_available() else
                        "mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: mps

# %% [markdown]
# Load the data

# %%
def generate_all_data_via_rolling_windows(
    price_parser,
    weather_parser,
    countries_list,
    weather_features,
    window_size=30,
    cointegration_period=250,
    stride=5,
    start_date="2015-01-01",
    end_date="2024-12-31"
):
    """
    Generates train/val/test data using a rolling cointegration window.

    Parameters:
        price_parser: PriceDataLoader object
        weather_parser: WeatherDataLoader object
        cointegration_period: int, window size for cointegration period (default=250)
        stride: int, how much to roll the window forward each time (default=5)
        start_date: str, beginning of date range for rolling windows
        end_date: str, end of date range for rolling windows

    Returns:
        Tuple of lists of train/val/test data and returns:
        (
            all_train_data, all_train_returns,
            all_val_data, all_val_returns,
            all_test_data, all_test_returns
        )
    """

    all_train_data, all_train_returns = [], []
    all_val_data, all_val_returns = [], []
    all_test_data, all_test_returns = [], []

    current_start = pd.to_datetime(start_date)
    final_end = pd.to_datetime(end_date)

    while current_start + timedelta(days=cointegration_period + 30 + 1) <= final_end:
        current_end = current_start + timedelta(days=cointegration_period)
        date_range = f"{current_start.date()},{current_end.date()}"
        print(f"----------------------Processing date range: {date_range}----------------------")

        # countries_list = list(set(price_parser.get_countries_with_complete_data(date_range)) &
        #                       set(weather_parser.get_country_list()))
        if not countries_list:
            current_start += timedelta(days=stride)
            continue

        # Generate price matrix
        price_matrix = price_parser.get_price_matrix(
            time_range=date_range,
            countries=countries_list,
            fill_method="ffill"
        )
        # print(f"Shape of price_matrix: {price_matrix.shape}")

        # Compute returns
        returns = price_matrix.pct_change().dropna()
        # print(f"Shape of returns: {returns.shape}")

        # Generate asset residuals using cointegration
        residual_generator = CointegrationResidualGenerator(price_matrix)
        residual_generator.compute_all_asset_residuals()
        asset_residuals = residual_generator.get_asset_residuals()

        # print(f"Number of total features (price + weather): {len(weather_features) * len(countries_list) + 1}")

        # Generate weather matrix
        weather_matrix = weather_parser.get_weather_matrix(
            time_range=date_range,
            countries=countries_list,
            fill_method="ffill",
            features=weather_features
        )
        # print(f"Shape of weather_matrix: {weather_matrix.shape}")


        dp = DataPreparation(
            price_residuals=asset_residuals,
            weather_data=weather_matrix,
            countries=countries_list,
            weather_features=weather_features
        )
        window_size = 30
        inner_stride = 1
        combined_data = dp.prepare_rolling_windows(window_size=window_size, stride=inner_stride) 
        # [num_samples, num_features, window_size]
        
        next_day_returns = dp.prepare_next_day_returns(returns=returns, window_size=window_size, stride=inner_stride)
        # [num_samples, num_countries]
        
        # Split the data in time-series
        (train_data, train_returns), (val_data, val_returns), (test_data, test_returns) = \
        dp.create_train_val_test_split(combined_data=combined_data, next_day_returns=next_day_returns)

        if train_data is not None and len(train_data) > 0:
            all_train_data.extend(train_data)
            all_train_returns.extend(train_returns)

        if val_data is not None and len(val_data) > 0:
            all_val_data.extend(val_data)
            all_val_returns.extend(val_returns)

        if test_data is not None and len(test_data) > 0:
            all_test_data.extend(test_data)
            all_test_returns.extend(test_returns)

        current_start += timedelta(days=stride)

    return (
        all_train_data, all_train_returns,
        all_val_data, all_val_returns,
        all_test_data, all_test_returns
    )


price_parser = PriceDataLoader(file_path="../data/european_wholesale_electricity_price_data_daily.csv")
weather_parser = WeatherDataLoader(file_path="../data/aggregated_weather.csv")

data_path = "data/all_data.pt"
force_regenerate = True

if os.path.exists(data_path) and not force_regenerate:
    # Load pre-saved data
    print("Loading pre-saved data...")
    checkpoint = torch.load(data_path)
    all_train_data = checkpoint["train_data"]
    all_train_returns = checkpoint["train_returns"]
    all_val_data = checkpoint["val_data"]
    all_val_returns = checkpoint["val_returns"]
    all_test_data = checkpoint["test_data"]
    all_test_returns = checkpoint["test_returns"]
else:
    # Generate data
    print("Generating data...")
    
    # Define the time range and valid countries
    start_date="2015-01-01"
    end_date="2024-12-31"
    time_range = f"{start_date},{end_date}"
    countries_list = list(set(price_parser.get_countries_with_complete_data(time_range)) & 
                     set(weather_parser.get_country_list()))
    
    # Define weather features
    weather_features = [
        'temperature_2m_mean', 'temperature_2m_min', 'temperature_2m_max',
        'precipitation_mean', 'precipitation_min', 'precipitation_max',
        'wind_speed_mean', 'wind_speed_min', 'wind_speed_max'
    ]

    # Define the window size
    window_size = 30 

    # Generate all data using rolling windows
    all_train_data, all_train_returns, all_val_data, all_val_returns, all_test_data, all_test_returns = generate_all_data_via_rolling_windows(
        price_parser,
        weather_parser,
        countries_list=countries_list,
        weather_features=weather_features,
        window_size=30,
        cointegration_period=365,
        stride=182, # 6 months stride
        start_date=start_date,
        end_date=end_date
    )

    # Save the result
    os.makedirs("data", exist_ok=True)
    torch.save({
        "train_data": all_train_data,
        "train_returns": all_train_returns,
        "val_data": all_val_data,
        "val_returns": all_val_returns,
        "test_data": all_test_data,
        "test_returns": all_test_returns
    }, data_path)
 
# Convert to tensors
train_data_tensor = torch.FloatTensor(all_train_data).to(device)
train_returns_tensor = torch.FloatTensor(all_train_returns).to(device)
val_data_tensor = torch.FloatTensor(all_val_data).to(device)
val_returns_tensor = torch.FloatTensor(all_val_returns).to(device)
test_data_tensor = torch.FloatTensor(all_test_data).to(device)
test_returns_tensor = torch.FloatTensor(all_test_returns).to(device)
# Out:
# Data loaded successfully from ../data/european_wholesale_electricity_price_data_daily.csv
# Weather data loaded successfully from ../data/aggregated_weather.csv
# Generating data...
# ----------------------Processing date range: 2015-01-01,2016-01-01----------------------
# Warning: Number of returns (335) does not match expected samples (336)
# ----------------------Processing date range: 2015-07-02,2016-07-01----------------------
# /Users/hansstem/.conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Warning: Number of returns (331) does not match expected samples (332)
# ----------------------Processing date range: 2015-12-31,2016-12-30----------------------
# /Users/hansstem/.conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Warning: Number of returns (327) does not match expected samples (328)
# ----------------------Processing date range: 2016-06-30,2017-06-30----------------------
# /Users/hansstem/.conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Warning: Number of returns (329) does not match expected samples (330)
# ----------------------Processing date range: 2016-12-29,2017-12-29----------------------
# /Users/hansstem/.conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Warning: Number of returns (327) does not match expected samples (328)
# ----------------------Processing date range: 2017-06-29,2018-06-29----------------------
# /Users/hansstem/.conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Warning: Number of returns (325) does not match expected samples (326)
# ----------------------Processing date range: 2017-12-28,2018-12-28----------------------
# /Users/hansstem/.conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Warning: Number of returns (331) does not match expected samples (332)
# ----------------------Processing date range: 2018-06-28,2019-06-28----------------------
# /Users/hansstem/.conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Warning: Number of returns (331) does not match expected samples (332)
# ----------------------Processing date range: 2018-12-27,2019-12-27----------------------
# /Users/hansstem/.conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Warning: Number of returns (329) does not match expected samples (330)
# ----------------------Processing date range: 2019-06-27,2020-06-26----------------------
# /Users/hansstem/.conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Warning: Number of returns (318) does not match expected samples (319)
# ----------------------Processing date range: 2019-12-26,2020-12-25----------------------
# /Users/hansstem/.conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Warning: Number of returns (318) does not match expected samples (319)
# ----------------------Processing date range: 2020-06-25,2021-06-25----------------------
# /Users/hansstem/.conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Warning: Number of returns (327) does not match expected samples (328)
# ----------------------Processing date range: 2020-12-24,2021-12-24----------------------
# /Users/hansstem/.conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Warning: Number of returns (329) does not match expected samples (330)
# ----------------------Processing date range: 2021-06-24,2022-06-24----------------------
# Warning: Number of returns (335) does not match expected samples (336)
# ----------------------Processing date range: 2021-12-23,2022-12-23----------------------
# Warning: Number of returns (335) does not match expected samples (336)
# ----------------------Processing date range: 2022-06-23,2023-06-23----------------------
# /Users/hansstem/.conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Warning: Number of returns (327) does not match expected samples (328)
# ----------------------Processing date range: 2022-12-22,2023-12-22----------------------
# /Users/hansstem/.conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Warning: Number of returns (304) does not match expected samples (305)
# ----------------------Processing date range: 2023-06-22,2024-06-21----------------------
# /Users/hansstem/.conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Warning: Number of returns (298) does not match expected samples (299)

# %%
print(f"Train data shape: {train_data_tensor.shape}") # [samples, num_features, window size]
print(f"Train returns shape: {train_returns_tensor.shape}") # [samples, num_countries (returns)]
# Out:
# Train data shape: torch.Size([4103, 240, 30])
# Train returns shape: torch.Size([4103, 24])

# %% [markdown]
# We initialize the portfolio optimizer and set up our trainer, which allows grid search for finding the best hyperparameters.

# %%
portfolio_optimizer = PortfolioOptimizer(
    window_size=window_size,
    num_countries=len(countries_list),
    num_weather_features=len(weather_features),
    num_filters=8,  # Default value
    filter_size=3,
    hidden_dim=64,
    num_heads=4,
    use_transformer=False,
    device=device
)

trainer = Trainer(
    optimizer=portfolio_optimizer,
    train_data=train_data_tensor,
    train_returns=train_returns_tensor,
    val_data=val_data_tensor,
    val_returns=val_returns_tensor,
    lr=0.0001,
    num_epochs=10000,
    batch_size=182,
    patience=50,
    device=device,
)

# Can add more parameters to test
param_grid = {
    'num_filters': [8, 16, 32],
    'filter_size': [3, 5, 7],
    'hidden_dim': [64, 128]
}
best_params, best_score, best_returns = trainer.grid_search(param_grid, verbose=False)
print(f"Best parameters: {best_params} with Sharpe Ratio: {best_score:.4f}")
# Out:
# Testing: num_filters=8, filter_size=3, hidden_dim=64
# Testing: num_filters=8, filter_size=3, hidden_dim=128
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 32
#      26 # Can add more parameters to test
#      27 param_grid = {
#      28     'num_filters': [8, 16, 32],
#      29     'filter_size': [3, 5, 7],
#      30     'hidden_dim': [64, 128]
#      31 }
# ---> 32 best_params, best_score, best_returns = trainer.grid_search(param_grid, verbose=False)
#      33 print(f"Best parameters: {best_params} with Sharpe Ratio: {best_score:.4f}")
#
# File ~/Documents/Studie fag/Vår 2025 Australia/STAT3007 Deep learning/Project/stat3007-deep-learning-project/src/Trainer.py:228, in Trainer.grid_search(self, param_grid, verbose)
#     225 self.torch_optimizer = optim.Adam(self.optimizer.get_parameters(), lr=self.lr)
#     227 # Train and evaluate model
# --> 228 sharpe, returns = self.train(verbose=verbose)
#     229 # Update best results if current Sharpe is better
#     230 if sharpe > best_score:
#
# File ~/Documents/Studie fag/Vår 2025 Australia/STAT3007 Deep learning/Project/stat3007-deep-learning-project/src/Trainer.py:158, in Trainer.train(self, verbose)
#     155 # Train for specified number of epochs
#     156 for epoch in range(self.num_epochs):
#     157     # Train for one epoch
# --> 158     self.train_epoch()
#     159     # Evaluate on validation set
#     160     train_sharpe = self.evaluate(self.train_data, self.train_returns)
#
# File ~/Documents/Studie fag/Vår 2025 Australia/STAT3007 Deep learning/Project/stat3007-deep-learning-project/src/Trainer.py:95, in Trainer.train_epoch(self)
#      93 self.torch_optimizer.zero_grad()
#      94 # Forward pass to get portfolio weights
# ---> 95 weights = self.optimizer.forward(batch_inputs)
#      96 # Compute portfolio returns as weighted sum of asset returns
#      97 portfolio_returns = torch.sum(weights * batch_returns, dim=1)
#
# File ~/Documents/Studie fag/Vår 2025 Australia/STAT3007 Deep learning/Project/stat3007-deep-learning-project/src/PortfolioOptimizer.py:150, in PortfolioOptimizer.forward(self, x)
#     140 def forward(self, x: torch.Tensor) -> torch.Tensor:
#     141     """
#     142     Forward pass to compute portfolio weights during training.
#     143
#    (...)
#     148         torch.Tensor: Computed portfolio weights of shape [batch_size, num_countries].
#     149     """
# --> 150     return self._compute_weights(x, training=True)
#
# File ~/Documents/Studie fag/Vår 2025 Australia/STAT3007 Deep learning/Project/stat3007-deep-learning-project/src/PortfolioOptimizer.py:114, in PortfolioOptimizer._compute_weights(self, x, training)
#     112     if isinstance(x, tuple):
#     113         x = x[0]  # Extract the output tensor
# --> 114 weights = self.ffn_model(x)
#     115 # normalize with tanh + softmax or L1
#     116 if not training:
#
# File ~/.conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Documents/Studie fag/Vår 2025 Australia/STAT3007 Deep learning/Project/stat3007-deep-learning-project/src/models/FFN.py:31, in FFN.forward(self, x)
#      21 def forward(self, x):
#      22     """
#      23     Forward pass through the network.
#      24
#    (...)
#      29         torch.Tensor: Output tensor of shape [batch_size, output_dim]
#      30     """
# ---> 31     x = F.relu(self.fc1(x))
#      32     #x = self.dropout(x)
#      33     x = F.relu(self.fc2(x))
#
# File ~/.conda/lib/python3.10/site-packages/torch/nn/functional.py:1704, in relu(input, inplace)
#    1702     result = torch.relu_(input)
#    1703 else:
# -> 1704     result = torch.relu(input)
#    1705 return result
#
# KeyboardInterrupt:

# %% [markdown]
# Reinitialize with best parameters and train on train+val

# %%
portfolio_optimizer = PortfolioOptimizer(
    window_size=window_size,
    num_countries=len(countries_list),
    num_weather_features=len(weather_features),
    num_filters=best_params['num_filters'],
    filter_size=best_params['filter_size'],
    hidden_dim=best_params['hidden_dim'],
    num_heads=4,
    use_transformer=False,
    device=device
)
trainer = Trainer(
    optimizer=portfolio_optimizer,
    train_data=torch.cat([train_data_tensor, val_data_tensor]),  # Combine train and val
    train_returns=torch.cat([train_returns_tensor, val_returns_tensor]),
    val_data=val_data_tensor,  # Still use val for early stopping
    val_returns=val_returns_tensor,
    lr=0.00001,
    num_epochs=100000,
    batch_size=182,
    patience=10000,
    device=device
)
final_sharpe, _ = trainer.train(verbose=True)
# Out:
# Epoch   0 | Train Sharpe: -0.0406 | Val Sharpe: -0.0820
# Epoch   1 | Train Sharpe: -0.0325 | Val Sharpe: -0.0504
# Epoch   2 | Train Sharpe: -0.0241 | Val Sharpe: -0.0179
# Epoch   3 | Train Sharpe: -0.0150 | Val Sharpe: 0.0141
# Epoch   4 | Train Sharpe: -0.0034 | Val Sharpe: 0.0470
# Epoch   5 | Train Sharpe: 0.0162 | Val Sharpe: 0.0824
# Epoch   6 | Train Sharpe: 0.0549 | Val Sharpe: 0.1253
# Epoch   7 | Train Sharpe: 0.0799 | Val Sharpe: 0.1448
# Epoch   8 | Train Sharpe: 0.1024 | Val Sharpe: 0.1624
# Epoch   9 | Train Sharpe: 0.1146 | Val Sharpe: 0.1723
# Epoch  10 | Train Sharpe: 0.1137 | Val Sharpe: 0.1787
# Epoch  11 | Train Sharpe: 0.1216 | Val Sharpe: 0.1811
# Epoch  12 | Train Sharpe: 0.1207 | Val Sharpe: 0.1828
# Epoch  13 | Train Sharpe: 0.1206 | Val Sharpe: 0.1840
# Epoch  14 | Train Sharpe: 0.1228 | Val Sharpe: 0.1846
# Epoch  15 | Train Sharpe: 0.1142 | Val Sharpe: 0.1844
# Epoch  16 | Train Sharpe: 0.1157 | Val Sharpe: 0.1854
# Epoch  17 | Train Sharpe: 0.1148 | Val Sharpe: 0.1859
# Epoch  18 | Train Sharpe: 0.1206 | Val Sharpe: 0.1870
# Epoch  19 | Train Sharpe: 0.1197 | Val Sharpe: 0.1875
# Epoch  20 | Train Sharpe: 0.1207 | Val Sharpe: 0.1876
# Epoch  21 | Train Sharpe: 0.1302 | Val Sharpe: 0.1898
# Epoch  22 | Train Sharpe: 0.1252 | Val Sharpe: 0.1899
# Epoch  23 | Train Sharpe: 0.1278 | Val Sharpe: 0.1899
# Epoch  24 | Train Sharpe: 0.1319 | Val Sharpe: 0.1907
# Epoch  25 | Train Sharpe: 0.1294 | Val Sharpe: 0.1921
# Epoch  26 | Train Sharpe: 0.1305 | Val Sharpe: 0.1921
# Epoch  27 | Train Sharpe: 0.1315 | Val Sharpe: 0.1918
# Epoch  28 | Train Sharpe: 0.1312 | Val Sharpe: 0.1922
# Epoch  29 | Train Sharpe: 0.1506 | Val Sharpe: 0.1903
# Epoch  30 | Train Sharpe: 0.1434 | Val Sharpe: 0.1934
# Epoch  31 | Train Sharpe: 0.1373 | Val Sharpe: 0.1939
# Epoch  32 | Train Sharpe: 0.1354 | Val Sharpe: 0.1940
# Epoch  33 | Train Sharpe: 0.1386 | Val Sharpe: 0.1940
# Epoch  34 | Train Sharpe: 0.1359 | Val Sharpe: 0.1937
# Epoch  35 | Train Sharpe: 0.1396 | Val Sharpe: 0.1940
# Epoch  36 | Train Sharpe: 0.1515 | Val Sharpe: 0.1940
# Epoch  37 | Train Sharpe: 0.1451 | Val Sharpe: 0.1954
# Epoch  38 | Train Sharpe: 0.1386 | Val Sharpe: 0.1950
# Epoch  39 | Train Sharpe: 0.1388 | Val Sharpe: 0.1946
# Epoch  40 | Train Sharpe: 0.1432 | Val Sharpe: 0.1967
# Epoch  41 | Train Sharpe: 0.1453 | Val Sharpe: 0.1964
# Epoch  42 | Train Sharpe: 0.1428 | Val Sharpe: 0.1967
# Epoch  43 | Train Sharpe: 0.1443 | Val Sharpe: 0.1967
# Epoch  44 | Train Sharpe: 0.1444 | Val Sharpe: 0.1967
# Epoch  45 | Train Sharpe: 0.1453 | Val Sharpe: 0.1966
# Epoch  46 | Train Sharpe: 0.1442 | Val Sharpe: 0.1963
# Epoch  47 | Train Sharpe: 0.1451 | Val Sharpe: 0.1967
# Epoch  48 | Train Sharpe: 0.1518 | Val Sharpe: 0.1978
# Epoch  49 | Train Sharpe: 0.1462 | Val Sharpe: 0.1981
# Epoch  50 | Train Sharpe: 0.1454 | Val Sharpe: 0.1979
# Epoch  51 | Train Sharpe: 0.1429 | Val Sharpe: 0.1973
# Epoch  52 | Train Sharpe: 0.1549 | Val Sharpe: 0.1990
# Epoch  53 | Train Sharpe: 0.1484 | Val Sharpe: 0.1996
# Epoch  54 | Train Sharpe: 0.1472 | Val Sharpe: 0.1994
# Epoch  55 | Train Sharpe: 0.1459 | Val Sharpe: 0.1991
# Epoch  56 | Train Sharpe: 0.1492 | Val Sharpe: 0.1999
# Epoch  57 | Train Sharpe: 0.1457 | Val Sharpe: 0.1996
# Epoch  58 | Train Sharpe: 0.1578 | Val Sharpe: 0.1997
# Epoch  59 | Train Sharpe: 0.1505 | Val Sharpe: 0.2014
# Epoch  60 | Train Sharpe: 0.1508 | Val Sharpe: 0.2013
# Epoch  61 | Train Sharpe: 0.1489 | Val Sharpe: 0.2017
# Epoch  62 | Train Sharpe: 0.1488 | Val Sharpe: 0.2016
# Epoch  63 | Train Sharpe: 0.1504 | Val Sharpe: 0.2014
# Epoch  64 | Train Sharpe: 0.1500 | Val Sharpe: 0.2018
# Epoch  65 | Train Sharpe: 0.1469 | Val Sharpe: 0.2015
# Epoch  66 | Train Sharpe: 0.1720 | Val Sharpe: 0.1947
# Epoch  67 | Train Sharpe: 0.1714 | Val Sharpe: 0.1980
# Epoch  68 | Train Sharpe: 0.1705 | Val Sharpe: 0.1996
# Epoch  69 | Train Sharpe: 0.1688 | Val Sharpe: 0.1999
# Epoch  70 | Train Sharpe: 0.1669 | Val Sharpe: 0.1996
# Epoch  71 | Train Sharpe: 0.1581 | Val Sharpe: 0.2025
# Epoch  72 | Train Sharpe: 0.1631 | Val Sharpe: 0.2009
# Epoch  73 | Train Sharpe: 0.1647 | Val Sharpe: 0.2010
# Epoch  74 | Train Sharpe: 0.1570 | Val Sharpe: 0.2019
# Epoch  75 | Train Sharpe: 0.1559 | Val Sharpe: 0.2026
# Epoch  76 | Train Sharpe: 0.1524 | Val Sharpe: 0.2020
# Epoch  77 | Train Sharpe: 0.1557 | Val Sharpe: 0.2039
# Epoch  78 | Train Sharpe: 0.1555 | Val Sharpe: 0.2032
# Epoch  79 | Train Sharpe: 0.1512 | Val Sharpe: 0.2037
# Epoch  80 | Train Sharpe: 0.1683 | Val Sharpe: 0.2018
# Epoch  81 | Train Sharpe: 0.1652 | Val Sharpe: 0.2024
# Epoch  82 | Train Sharpe: 0.1667 | Val Sharpe: 0.2024
# Epoch  83 | Train Sharpe: 0.1667 | Val Sharpe: 0.2025
# Epoch  84 | Train Sharpe: 0.1667 | Val Sharpe: 0.2022
# Epoch  85 | Train Sharpe: 0.1631 | Val Sharpe: 0.2039
# Epoch  86 | Train Sharpe: 0.1680 | Val Sharpe: 0.2025
# Epoch  87 | Train Sharpe: 0.1632 | Val Sharpe: 0.2033
# Epoch  88 | Train Sharpe: 0.1501 | Val Sharpe: 0.2038
# Epoch  89 | Train Sharpe: 0.1541 | Val Sharpe: 0.2039
# Epoch  90 | Train Sharpe: 0.1561 | Val Sharpe: 0.2034
# Epoch  91 | Train Sharpe: 0.1530 | Val Sharpe: 0.2019
# Epoch  92 | Train Sharpe: 0.1567 | Val Sharpe: 0.2049
# Epoch  93 | Train Sharpe: 0.1570 | Val Sharpe: 0.2042
# Epoch  94 | Train Sharpe: 0.1577 | Val Sharpe: 0.2043
# Epoch  95 | Train Sharpe: 0.1580 | Val Sharpe: 0.2040
# Epoch  96 | Train Sharpe: 0.1571 | Val Sharpe: 0.2038
# Epoch  97 | Train Sharpe: 0.1498 | Val Sharpe: 0.2026
# Epoch  98 | Train Sharpe: 0.1551 | Val Sharpe: 0.2045
# Epoch  99 | Train Sharpe: 0.1554 | Val Sharpe: 0.2065
# Epoch 100 | Train Sharpe: 0.1554 | Val Sharpe: 0.2058
# Epoch 101 | Train Sharpe: 0.1563 | Val Sharpe: 0.2059
# Epoch 102 | Train Sharpe: 0.1571 | Val Sharpe: 0.2058
# Epoch 103 | Train Sharpe: 0.1578 | Val Sharpe: 0.2058
# Epoch 104 | Train Sharpe: 0.1583 | Val Sharpe: 0.2058
# Epoch 105 | Train Sharpe: 0.1587 | Val Sharpe: 0.2058
# Epoch 106 | Train Sharpe: 0.1586 | Val Sharpe: 0.2057
# Epoch 107 | Train Sharpe: 0.1563 | Val Sharpe: 0.2053
# Epoch 108 | Train Sharpe: 0.1559 | Val Sharpe: 0.2072
# Epoch 109 | Train Sharpe: 0.1559 | Val Sharpe: 0.2066
# Epoch 110 | Train Sharpe: 0.1567 | Val Sharpe: 0.2067
# Epoch 111 | Train Sharpe: 0.1573 | Val Sharpe: 0.2066
# Epoch 112 | Train Sharpe: 0.1579 | Val Sharpe: 0.2066
# Epoch 113 | Train Sharpe: 0.1584 | Val Sharpe: 0.2066
# Epoch 114 | Train Sharpe: 0.1585 | Val Sharpe: 0.2065
# Epoch 115 | Train Sharpe: 0.1579 | Val Sharpe: 0.2063
# Epoch 116 | Train Sharpe: 0.1521 | Val Sharpe: 0.2055
# Epoch 117 | Train Sharpe: 0.1573 | Val Sharpe: 0.2071
# Epoch 118 | Train Sharpe: 0.1511 | Val Sharpe: 0.2056
# Epoch 119 | Train Sharpe: 0.1563 | Val Sharpe: 0.2070
# Epoch 120 | Train Sharpe: 0.1546 | Val Sharpe: 0.2062
# Epoch 121 | Train Sharpe: 0.1540 | Val Sharpe: 0.2081
# Epoch 122 | Train Sharpe: 0.1539 | Val Sharpe: 0.2074
# Epoch 123 | Train Sharpe: 0.1548 | Val Sharpe: 0.2075
# Epoch 124 | Train Sharpe: 0.1556 | Val Sharpe: 0.2074
# Epoch 125 | Train Sharpe: 0.1563 | Val Sharpe: 0.2074
# Epoch 126 | Train Sharpe: 0.1570 | Val Sharpe: 0.2074
# Epoch 127 | Train Sharpe: 0.1576 | Val Sharpe: 0.2074
# Epoch 128 | Train Sharpe: 0.1580 | Val Sharpe: 0.2074
# Epoch 129 | Train Sharpe: 0.1582 | Val Sharpe: 0.2072
# Epoch 130 | Train Sharpe: 0.1575 | Val Sharpe: 0.2070
# Epoch 131 | Train Sharpe: 0.1514 | Val Sharpe: 0.2062
# Epoch 132 | Train Sharpe: 0.1563 | Val Sharpe: 0.2075
# Epoch 133 | Train Sharpe: 0.1523 | Val Sharpe: 0.2065
# Epoch 134 | Train Sharpe: 0.1572 | Val Sharpe: 0.2079
# Epoch 135 | Train Sharpe: 0.1560 | Val Sharpe: 0.2071
# Epoch 136 | Train Sharpe: 0.1492 | Val Sharpe: 0.2063
# Epoch 137 | Train Sharpe: 0.1535 | Val Sharpe: 0.2074
# Epoch 138 | Train Sharpe: 0.1552 | Val Sharpe: 0.2085
# Epoch 139 | Train Sharpe: 0.1554 | Val Sharpe: 0.2079
# Epoch 140 | Train Sharpe: 0.1562 | Val Sharpe: 0.2079
# Epoch 141 | Train Sharpe: 0.1569 | Val Sharpe: 0.2078
# Epoch 142 | Train Sharpe: 0.1573 | Val Sharpe: 0.2078
# Epoch 143 | Train Sharpe: 0.1575 | Val Sharpe: 0.2077
# Epoch 144 | Train Sharpe: 0.1566 | Val Sharpe: 0.2075
# Epoch 145 | Train Sharpe: 0.1495 | Val Sharpe: 0.2066
# Epoch 146 | Train Sharpe: 0.1538 | Val Sharpe: 0.2077
# Epoch 147 | Train Sharpe: 0.1550 | Val Sharpe: 0.2088
# Epoch 148 | Train Sharpe: 0.1552 | Val Sharpe: 0.2082
# Epoch 149 | Train Sharpe: 0.1560 | Val Sharpe: 0.2082
# Epoch 150 | Train Sharpe: 0.1567 | Val Sharpe: 0.2081
# Epoch 151 | Train Sharpe: 0.1572 | Val Sharpe: 0.2081
# Epoch 152 | Train Sharpe: 0.1577 | Val Sharpe: 0.2080
# Epoch 153 | Train Sharpe: 0.1577 | Val Sharpe: 0.2079
# Epoch 154 | Train Sharpe: 0.1566 | Val Sharpe: 0.2077
# Epoch 155 | Train Sharpe: 0.1492 | Val Sharpe: 0.2069
# Epoch 156 | Train Sharpe: 0.1534 | Val Sharpe: 0.2079
# Epoch 157 | Train Sharpe: 0.1564 | Val Sharpe: 0.2089
# Epoch 158 | Train Sharpe: 0.1566 | Val Sharpe: 0.2084
# Epoch 159 | Train Sharpe: 0.1572 | Val Sharpe: 0.2082
# Epoch 160 | Train Sharpe: 0.1575 | Val Sharpe: 0.2081
# Epoch 161 | Train Sharpe: 0.1570 | Val Sharpe: 0.2079
# Epoch 162 | Train Sharpe: 0.1525 | Val Sharpe: 0.2073
# Epoch 163 | Train Sharpe: 0.1573 | Val Sharpe: 0.2086
# Epoch 164 | Train Sharpe: 0.1562 | Val Sharpe: 0.2079
# Epoch 165 | Train Sharpe: 0.1495 | Val Sharpe: 0.2071
# Epoch 166 | Train Sharpe: 0.1536 | Val Sharpe: 0.2080
# Epoch 167 | Train Sharpe: 0.1561 | Val Sharpe: 0.2090
# Epoch 168 | Train Sharpe: 0.1563 | Val Sharpe: 0.2085
# Epoch 169 | Train Sharpe: 0.1571 | Val Sharpe: 0.2084
# Epoch 170 | Train Sharpe: 0.1575 | Val Sharpe: 0.2083
# Epoch 171 | Train Sharpe: 0.1576 | Val Sharpe: 0.2082
# Epoch 172 | Train Sharpe: 0.1565 | Val Sharpe: 0.2080
# Epoch 173 | Train Sharpe: 0.1496 | Val Sharpe: 0.2071
# Epoch 174 | Train Sharpe: 0.1537 | Val Sharpe: 0.2081
# Epoch 175 | Train Sharpe: 0.1561 | Val Sharpe: 0.2092
# Epoch 176 | Train Sharpe: 0.1563 | Val Sharpe: 0.2088
# Epoch 177 | Train Sharpe: 0.1570 | Val Sharpe: 0.2087
# Epoch 178 | Train Sharpe: 0.1575 | Val Sharpe: 0.2085
# Epoch 179 | Train Sharpe: 0.1577 | Val Sharpe: 0.2084
# Epoch 180 | Train Sharpe: 0.1570 | Val Sharpe: 0.2081
# Epoch 181 | Train Sharpe: 0.1517 | Val Sharpe: 0.2073
# Epoch 182 | Train Sharpe: 0.1564 | Val Sharpe: 0.2084
# Epoch 183 | Train Sharpe: 0.1512 | Val Sharpe: 0.2072
# Epoch 184 | Train Sharpe: 0.1558 | Val Sharpe: 0.2083
# Epoch 185 | Train Sharpe: 0.1575 | Val Sharpe: 0.2083
# Epoch 186 | Train Sharpe: 0.1568 | Val Sharpe: 0.2080
# Epoch 187 | Train Sharpe: 0.1506 | Val Sharpe: 0.2072
# Epoch 188 | Train Sharpe: 0.1548 | Val Sharpe: 0.2082
# Epoch 189 | Train Sharpe: 0.1551 | Val Sharpe: 0.2091
# Epoch 190 | Train Sharpe: 0.1552 | Val Sharpe: 0.2086
# Epoch 191 | Train Sharpe: 0.1560 | Val Sharpe: 0.2087
# Epoch 192 | Train Sharpe: 0.1568 | Val Sharpe: 0.2087
# Epoch 193 | Train Sharpe: 0.1574 | Val Sharpe: 0.2087
# Epoch 194 | Train Sharpe: 0.1579 | Val Sharpe: 0.2087
# Epoch 195 | Train Sharpe: 0.1582 | Val Sharpe: 0.2086
# Epoch 196 | Train Sharpe: 0.1583 | Val Sharpe: 0.2085
# Epoch 197 | Train Sharpe: 0.1575 | Val Sharpe: 0.2083
# Epoch 198 | Train Sharpe: 0.1514 | Val Sharpe: 0.2073
# Epoch 199 | Train Sharpe: 0.1557 | Val Sharpe: 0.2083
# Epoch 200 | Train Sharpe: 0.1558 | Val Sharpe: 0.2093
# Epoch 201 | Train Sharpe: 0.1559 | Val Sharpe: 0.2088
# Epoch 202 | Train Sharpe: 0.1567 | Val Sharpe: 0.2088
# Epoch 203 | Train Sharpe: 0.1574 | Val Sharpe: 0.2088
# Epoch 204 | Train Sharpe: 0.1581 | Val Sharpe: 0.2088
# Epoch 205 | Train Sharpe: 0.1586 | Val Sharpe: 0.2088
# Epoch 206 | Train Sharpe: 0.1590 | Val Sharpe: 0.2087
# Epoch 207 | Train Sharpe: 0.1591 | Val Sharpe: 0.2086
# Epoch 208 | Train Sharpe: 0.1586 | Val Sharpe: 0.2084
# Epoch 209 | Train Sharpe: 0.1554 | Val Sharpe: 0.2078
# Epoch 210 | Train Sharpe: 0.1584 | Val Sharpe: 0.2094
# Epoch 211 | Train Sharpe: 0.1585 | Val Sharpe: 0.2088
# Epoch 212 | Train Sharpe: 0.1590 | Val Sharpe: 0.2088
# Epoch 213 | Train Sharpe: 0.1592 | Val Sharpe: 0.2086
# Epoch 214 | Train Sharpe: 0.1589 | Val Sharpe: 0.2084
# Epoch 215 | Train Sharpe: 0.1564 | Val Sharpe: 0.2080
# Epoch 216 | Train Sharpe: 0.1563 | Val Sharpe: 0.2095
# Epoch 217 | Train Sharpe: 0.1563 | Val Sharpe: 0.2090
# Epoch 218 | Train Sharpe: 0.1571 | Val Sharpe: 0.2091
# Epoch 219 | Train Sharpe: 0.1578 | Val Sharpe: 0.2090
# Epoch 220 | Train Sharpe: 0.1585 | Val Sharpe: 0.2090
# Epoch 221 | Train Sharpe: 0.1591 | Val Sharpe: 0.2090
# Epoch 222 | Train Sharpe: 0.1595 | Val Sharpe: 0.2089
# Epoch 223 | Train Sharpe: 0.1598 | Val Sharpe: 0.2088
# Epoch 224 | Train Sharpe: 0.1598 | Val Sharpe: 0.2086
# Epoch 225 | Train Sharpe: 0.1585 | Val Sharpe: 0.2083
# Epoch 226 | Train Sharpe: 0.1554 | Val Sharpe: 0.2077
# Epoch 227 | Train Sharpe: 0.1596 | Val Sharpe: 0.2090
# Epoch 228 | Train Sharpe: 0.1593 | Val Sharpe: 0.2084
# Epoch 229 | Train Sharpe: 0.1579 | Val Sharpe: 0.2082
# Epoch 230 | Train Sharpe: 0.1584 | Val Sharpe: 0.2082
# Epoch 231 | Train Sharpe: 0.1527 | Val Sharpe: 0.2074
# Epoch 232 | Train Sharpe: 0.1569 | Val Sharpe: 0.2083
# Epoch 233 | Train Sharpe: 0.1567 | Val Sharpe: 0.2092
# Epoch 234 | Train Sharpe: 0.1569 | Val Sharpe: 0.2088
# Epoch 235 | Train Sharpe: 0.1577 | Val Sharpe: 0.2089
# Epoch 236 | Train Sharpe: 0.1584 | Val Sharpe: 0.2089
# Epoch 237 | Train Sharpe: 0.1591 | Val Sharpe: 0.2089
# Epoch 238 | Train Sharpe: 0.1596 | Val Sharpe: 0.2088
# Epoch 239 | Train Sharpe: 0.1600 | Val Sharpe: 0.2087
# Epoch 240 | Train Sharpe: 0.1600 | Val Sharpe: 0.2086
# Epoch 241 | Train Sharpe: 0.1585 | Val Sharpe: 0.2082
# Epoch 242 | Train Sharpe: 0.1583 | Val Sharpe: 0.2081
# Epoch 243 | Train Sharpe: 0.1596 | Val Sharpe: 0.2084
# Epoch 244 | Train Sharpe: 0.1574 | Val Sharpe: 0.2079
# Epoch 245 | Train Sharpe: 0.1572 | Val Sharpe: 0.2094
# Epoch 246 | Train Sharpe: 0.1572 | Val Sharpe: 0.2088
# Epoch 247 | Train Sharpe: 0.1580 | Val Sharpe: 0.2090
# Epoch 248 | Train Sharpe: 0.1588 | Val Sharpe: 0.2089
# Epoch 249 | Train Sharpe: 0.1594 | Val Sharpe: 0.2089
# Epoch 250 | Train Sharpe: 0.1600 | Val Sharpe: 0.2088
# Epoch 251 | Train Sharpe: 0.1605 | Val Sharpe: 0.2087
# Epoch 252 | Train Sharpe: 0.1606 | Val Sharpe: 0.2086
# Epoch 253 | Train Sharpe: 0.1600 | Val Sharpe: 0.2084
# Epoch 254 | Train Sharpe: 0.1548 | Val Sharpe: 0.2076
# Epoch 255 | Train Sharpe: 0.1592 | Val Sharpe: 0.2086
# Epoch 256 | Train Sharpe: 0.1540 | Val Sharpe: 0.2074
# Epoch 257 | Train Sharpe: 0.1584 | Val Sharpe: 0.2084
# Epoch 258 | Train Sharpe: 0.1599 | Val Sharpe: 0.2083
# Epoch 259 | Train Sharpe: 0.1588 | Val Sharpe: 0.2081
# Epoch 260 | Train Sharpe: 0.1541 | Val Sharpe: 0.2074
# Epoch 261 | Train Sharpe: 0.1585 | Val Sharpe: 0.2084
# Epoch 262 | Train Sharpe: 0.1573 | Val Sharpe: 0.2077
# Epoch 263 | Train Sharpe: 0.1571 | Val Sharpe: 0.2093
# Epoch 264 | Train Sharpe: 0.1572 | Val Sharpe: 0.2087
# Epoch 265 | Train Sharpe: 0.1581 | Val Sharpe: 0.2089
# Epoch 266 | Train Sharpe: 0.1589 | Val Sharpe: 0.2088
# Epoch 267 | Train Sharpe: 0.1597 | Val Sharpe: 0.2089
# Epoch 268 | Train Sharpe: 0.1603 | Val Sharpe: 0.2088
# Epoch 269 | Train Sharpe: 0.1608 | Val Sharpe: 0.2087
# Epoch 270 | Train Sharpe: 0.1611 | Val Sharpe: 0.2086
# Epoch 271 | Train Sharpe: 0.1607 | Val Sharpe: 0.2084
# Epoch 272 | Train Sharpe: 0.1571 | Val Sharpe: 0.2078
# Epoch 273 | Train Sharpe: 0.1608 | Val Sharpe: 0.2091
# Epoch 274 | Train Sharpe: 0.1608 | Val Sharpe: 0.2084
# Epoch 275 | Train Sharpe: 0.1608 | Val Sharpe: 0.2085
# Epoch 276 | Train Sharpe: 0.1589 | Val Sharpe: 0.2079
# Epoch 277 | Train Sharpe: 0.1598 | Val Sharpe: 0.2091
# Epoch 278 | Train Sharpe: 0.1599 | Val Sharpe: 0.2086
# Epoch 279 | Train Sharpe: 0.1606 | Val Sharpe: 0.2088
# Epoch 280 | Train Sharpe: 0.1611 | Val Sharpe: 0.2087
# Epoch 281 | Train Sharpe: 0.1615 | Val Sharpe: 0.2086
# Epoch 282 | Train Sharpe: 0.1613 | Val Sharpe: 0.2084
# Epoch 283 | Train Sharpe: 0.1590 | Val Sharpe: 0.2079
# Epoch 284 | Train Sharpe: 0.1589 | Val Sharpe: 0.2095
# Epoch 285 | Train Sharpe: 0.1589 | Val Sharpe: 0.2088
# Epoch 286 | Train Sharpe: 0.1597 | Val Sharpe: 0.2090
# Epoch 287 | Train Sharpe: 0.1604 | Val Sharpe: 0.2089
# Epoch 288 | Train Sharpe: 0.1611 | Val Sharpe: 0.2089
# Epoch 289 | Train Sharpe: 0.1617 | Val Sharpe: 0.2088
# Epoch 290 | Train Sharpe: 0.1621 | Val Sharpe: 0.2087
# Epoch 291 | Train Sharpe: 0.1623 | Val Sharpe: 0.2085
# Epoch 292 | Train Sharpe: 0.1619 | Val Sharpe: 0.2083
# Epoch 293 | Train Sharpe: 0.1578 | Val Sharpe: 0.2076
# Epoch 294 | Train Sharpe: 0.1621 | Val Sharpe: 0.2089
# Epoch 295 | Train Sharpe: 0.1615 | Val Sharpe: 0.2081
# Epoch 296 | Train Sharpe: 0.1584 | Val Sharpe: 0.2077
# Epoch 297 | Train Sharpe: 0.1618 | Val Sharpe: 0.2091
# Epoch 298 | Train Sharpe: 0.1618 | Val Sharpe: 0.2084
# Epoch 299 | Train Sharpe: 0.1621 | Val Sharpe: 0.2084
# Epoch 300 | Train Sharpe: 0.1614 | Val Sharpe: 0.2080
# Epoch 301 | Train Sharpe: 0.1559 | Val Sharpe: 0.2073
# Epoch 302 | Train Sharpe: 0.1600 | Val Sharpe: 0.2082
# Epoch 303 | Train Sharpe: 0.1606 | Val Sharpe: 0.2090
# Epoch 304 | Train Sharpe: 0.1608 | Val Sharpe: 0.2086
# Epoch 305 | Train Sharpe: 0.1615 | Val Sharpe: 0.2087
# Epoch 306 | Train Sharpe: 0.1621 | Val Sharpe: 0.2086
# Epoch 307 | Train Sharpe: 0.1625 | Val Sharpe: 0.2085
# Epoch 308 | Train Sharpe: 0.1625 | Val Sharpe: 0.2083
# Epoch 309 | Train Sharpe: 0.1611 | Val Sharpe: 0.2079
# Epoch 310 | Train Sharpe: 0.1613 | Val Sharpe: 0.2080
# Epoch 311 | Train Sharpe: 0.1579 | Val Sharpe: 0.2074
# Epoch 312 | Train Sharpe: 0.1622 | Val Sharpe: 0.2087
# Epoch 313 | Train Sharpe: 0.1613 | Val Sharpe: 0.2078
# Epoch 314 | Train Sharpe: 0.1557 | Val Sharpe: 0.2072
# Epoch 315 | Train Sharpe: 0.1597 | Val Sharpe: 0.2080
# Epoch 316 | Train Sharpe: 0.1597 | Val Sharpe: 0.2091
# Epoch 317 | Train Sharpe: 0.1599 | Val Sharpe: 0.2085
# Epoch 318 | Train Sharpe: 0.1607 | Val Sharpe: 0.2087
# Epoch 319 | Train Sharpe: 0.1615 | Val Sharpe: 0.2086
# Epoch 320 | Train Sharpe: 0.1621 | Val Sharpe: 0.2086
# Epoch 321 | Train Sharpe: 0.1626 | Val Sharpe: 0.2085
# Epoch 322 | Train Sharpe: 0.1628 | Val Sharpe: 0.2084
# Epoch 323 | Train Sharpe: 0.1624 | Val Sharpe: 0.2081
# Epoch 324 | Train Sharpe: 0.1585 | Val Sharpe: 0.2074
# Epoch 325 | Train Sharpe: 0.1626 | Val Sharpe: 0.2087
# Epoch 326 | Train Sharpe: 0.1618 | Val Sharpe: 0.2080
# Epoch 327 | Train Sharpe: 0.1572 | Val Sharpe: 0.2074
# Epoch 328 | Train Sharpe: 0.1615 | Val Sharpe: 0.2084
# Epoch 329 | Train Sharpe: 0.1566 | Val Sharpe: 0.2071
# Epoch 330 | Train Sharpe: 0.1608 | Val Sharpe: 0.2082
# Epoch 331 | Train Sharpe: 0.1613 | Val Sharpe: 0.2078
# Epoch 332 | Train Sharpe: 0.1562 | Val Sharpe: 0.2071
# Epoch 333 | Train Sharpe: 0.1603 | Val Sharpe: 0.2081
# Epoch 334 | Train Sharpe: 0.1616 | Val Sharpe: 0.2086
# Epoch 335 | Train Sharpe: 0.1619 | Val Sharpe: 0.2082
# Epoch 336 | Train Sharpe: 0.1623 | Val Sharpe: 0.2083
# Epoch 337 | Train Sharpe: 0.1621 | Val Sharpe: 0.2080
# Epoch 338 | Train Sharpe: 0.1593 | Val Sharpe: 0.2075
# Epoch 339 | Train Sharpe: 0.1617 | Val Sharpe: 0.2091
# Epoch 340 | Train Sharpe: 0.1618 | Val Sharpe: 0.2083
# Epoch 341 | Train Sharpe: 0.1624 | Val Sharpe: 0.2085
# Epoch 342 | Train Sharpe: 0.1627 | Val Sharpe: 0.2083
# Epoch 343 | Train Sharpe: 0.1626 | Val Sharpe: 0.2081
# Epoch 344 | Train Sharpe: 0.1604 | Val Sharpe: 0.2076
# Epoch 345 | Train Sharpe: 0.1609 | Val Sharpe: 0.2092
# Epoch 346 | Train Sharpe: 0.1610 | Val Sharpe: 0.2085
# Epoch 347 | Train Sharpe: 0.1617 | Val Sharpe: 0.2087
# Epoch 348 | Train Sharpe: 0.1624 | Val Sharpe: 0.2086
# Epoch 349 | Train Sharpe: 0.1629 | Val Sharpe: 0.2085
# Epoch 350 | Train Sharpe: 0.1633 | Val Sharpe: 0.2084
# Epoch 351 | Train Sharpe: 0.1635 | Val Sharpe: 0.2083
# Epoch 352 | Train Sharpe: 0.1629 | Val Sharpe: 0.2080
# Epoch 353 | Train Sharpe: 0.1581 | Val Sharpe: 0.2072
# Epoch 354 | Train Sharpe: 0.1624 | Val Sharpe: 0.2083
# Epoch 355 | Train Sharpe: 0.1574 | Val Sharpe: 0.2069
# Epoch 356 | Train Sharpe: 0.1616 | Val Sharpe: 0.2081
# Epoch 357 | Train Sharpe: 0.1609 | Val Sharpe: 0.2074
# Epoch 358 | Train Sharpe: 0.1624 | Val Sharpe: 0.2086
# Epoch 359 | Train Sharpe: 0.1625 | Val Sharpe: 0.2081
# Epoch 360 | Train Sharpe: 0.1630 | Val Sharpe: 0.2082
# Epoch 361 | Train Sharpe: 0.1630 | Val Sharpe: 0.2080
# Epoch 362 | Train Sharpe: 0.1616 | Val Sharpe: 0.2076
# Epoch 363 | Train Sharpe: 0.1624 | Val Sharpe: 0.2078
# Epoch 364 | Train Sharpe: 0.1572 | Val Sharpe: 0.2068
# Epoch 365 | Train Sharpe: 0.1613 | Val Sharpe: 0.2079
# Epoch 366 | Train Sharpe: 0.1627 | Val Sharpe: 0.2079
# Epoch 367 | Train Sharpe: 0.1618 | Val Sharpe: 0.2077
# Epoch 368 | Train Sharpe: 0.1565 | Val Sharpe: 0.2068
# Epoch 369 | Train Sharpe: 0.1604 | Val Sharpe: 0.2078
# Epoch 370 | Train Sharpe: 0.1607 | Val Sharpe: 0.2088
# Epoch 371 | Train Sharpe: 0.1608 | Val Sharpe: 0.2083
# Epoch 372 | Train Sharpe: 0.1617 | Val Sharpe: 0.2085
# Epoch 373 | Train Sharpe: 0.1624 | Val Sharpe: 0.2084
# Epoch 374 | Train Sharpe: 0.1629 | Val Sharpe: 0.2083
# Epoch 375 | Train Sharpe: 0.1634 | Val Sharpe: 0.2082
# Epoch 376 | Train Sharpe: 0.1634 | Val Sharpe: 0.2080
# Epoch 377 | Train Sharpe: 0.1624 | Val Sharpe: 0.2077
# Epoch 378 | Train Sharpe: 0.1580 | Val Sharpe: 0.2070
# Epoch 379 | Train Sharpe: 0.1622 | Val Sharpe: 0.2080
# Epoch 380 | Train Sharpe: 0.1580 | Val Sharpe: 0.2068
# Epoch 381 | Train Sharpe: 0.1624 | Val Sharpe: 0.2081
# Epoch 382 | Train Sharpe: 0.1573 | Val Sharpe: 0.2069
# Epoch 383 | Train Sharpe: 0.1619 | Val Sharpe: 0.2080
# Epoch 384 | Train Sharpe: 0.1575 | Val Sharpe: 0.2067
# Epoch 385 | Train Sharpe: 0.1618 | Val Sharpe: 0.2080
# Epoch 386 | Train Sharpe: 0.1581 | Val Sharpe: 0.2068
# Epoch 387 | Train Sharpe: 0.1625 | Val Sharpe: 0.2082
# Epoch 388 | Train Sharpe: 0.1595 | Val Sharpe: 0.2070
# Epoch 389 | Train Sharpe: 0.1624 | Val Sharpe: 0.2088
# Epoch 390 | Train Sharpe: 0.1625 | Val Sharpe: 0.2080
# Epoch 391 | Train Sharpe: 0.1630 | Val Sharpe: 0.2081
# Epoch 392 | Train Sharpe: 0.1631 | Val Sharpe: 0.2079
# Epoch 393 | Train Sharpe: 0.1617 | Val Sharpe: 0.2075
# Epoch 394 | Train Sharpe: 0.1632 | Val Sharpe: 0.2079
# Epoch 395 | Train Sharpe: 0.1611 | Val Sharpe: 0.2072
# Epoch 396 | Train Sharpe: 0.1618 | Val Sharpe: 0.2089
# Epoch 397 | Train Sharpe: 0.1619 | Val Sharpe: 0.2082
# Epoch 398 | Train Sharpe: 0.1626 | Val Sharpe: 0.2084
# Epoch 399 | Train Sharpe: 0.1632 | Val Sharpe: 0.2083
# Epoch 400 | Train Sharpe: 0.1637 | Val Sharpe: 0.2082
# Epoch 401 | Train Sharpe: 0.1639 | Val Sharpe: 0.2081
# Epoch 402 | Train Sharpe: 0.1636 | Val Sharpe: 0.2078
# Epoch 403 | Train Sharpe: 0.1600 | Val Sharpe: 0.2071
# Epoch 404 | Train Sharpe: 0.1638 | Val Sharpe: 0.2085
# Epoch 405 | Train Sharpe: 0.1634 | Val Sharpe: 0.2077
# Epoch 406 | Train Sharpe: 0.1616 | Val Sharpe: 0.2074
# Epoch 407 | Train Sharpe: 0.1625 | Val Sharpe: 0.2088
# Epoch 408 | Train Sharpe: 0.1627 | Val Sharpe: 0.2082
# Epoch 409 | Train Sharpe: 0.1633 | Val Sharpe: 0.2083
# Epoch 410 | Train Sharpe: 0.1638 | Val Sharpe: 0.2082
# Epoch 411 | Train Sharpe: 0.1642 | Val Sharpe: 0.2081
# Epoch 412 | Train Sharpe: 0.1641 | Val Sharpe: 0.2079
# Epoch 413 | Train Sharpe: 0.1626 | Val Sharpe: 0.2075
# Epoch 414 | Train Sharpe: 0.1639 | Val Sharpe: 0.2079
# Epoch 415 | Train Sharpe: 0.1613 | Val Sharpe: 0.2071
# Epoch 416 | Train Sharpe: 0.1626 | Val Sharpe: 0.2089
# Epoch 417 | Train Sharpe: 0.1626 | Val Sharpe: 0.2082
# Epoch 418 | Train Sharpe: 0.1633 | Val Sharpe: 0.2083
# Epoch 419 | Train Sharpe: 0.1639 | Val Sharpe: 0.2082
# Epoch 420 | Train Sharpe: 0.1643 | Val Sharpe: 0.2081
# Epoch 421 | Train Sharpe: 0.1644 | Val Sharpe: 0.2080
# Epoch 422 | Train Sharpe: 0.1638 | Val Sharpe: 0.2077
# Epoch 423 | Train Sharpe: 0.1591 | Val Sharpe: 0.2068
# Epoch 424 | Train Sharpe: 0.1632 | Val Sharpe: 0.2079
# Epoch 425 | Train Sharpe: 0.1597 | Val Sharpe: 0.2067
# Epoch 426 | Train Sharpe: 0.1639 | Val Sharpe: 0.2082
# Epoch 427 | Train Sharpe: 0.1623 | Val Sharpe: 0.2073
# Epoch 428 | Train Sharpe: 0.1635 | Val Sharpe: 0.2078
# Epoch 429 | Train Sharpe: 0.1601 | Val Sharpe: 0.2068
# Epoch 430 | Train Sharpe: 0.1639 | Val Sharpe: 0.2084
# Epoch 431 | Train Sharpe: 0.1636 | Val Sharpe: 0.2076
# Epoch 432 | Train Sharpe: 0.1622 | Val Sharpe: 0.2074
# Epoch 433 | Train Sharpe: 0.1640 | Val Sharpe: 0.2080
# Epoch 434 | Train Sharpe: 0.1634 | Val Sharpe: 0.2075
# Epoch 435 | Train Sharpe: 0.1598 | Val Sharpe: 0.2069
# Epoch 436 | Train Sharpe: 0.1638 | Val Sharpe: 0.2082
# Epoch 437 | Train Sharpe: 0.1629 | Val Sharpe: 0.2074
# Epoch 438 | Train Sharpe: 0.1585 | Val Sharpe: 0.2068
# Epoch 439 | Train Sharpe: 0.1625 | Val Sharpe: 0.2078
# Epoch 440 | Train Sharpe: 0.1617 | Val Sharpe: 0.2071
# Epoch 441 | Train Sharpe: 0.1629 | Val Sharpe: 0.2085
# Epoch 442 | Train Sharpe: 0.1631 | Val Sharpe: 0.2080
# Epoch 443 | Train Sharpe: 0.1637 | Val Sharpe: 0.2081
# Epoch 444 | Train Sharpe: 0.1640 | Val Sharpe: 0.2079
# Epoch 445 | Train Sharpe: 0.1640 | Val Sharpe: 0.2077
# Epoch 446 | Train Sharpe: 0.1623 | Val Sharpe: 0.2073
# Epoch 447 | Train Sharpe: 0.1638 | Val Sharpe: 0.2084
# Epoch 448 | Train Sharpe: 0.1639 | Val Sharpe: 0.2079
# Epoch 449 | Train Sharpe: 0.1642 | Val Sharpe: 0.2080
# Epoch 450 | Train Sharpe: 0.1640 | Val Sharpe: 0.2077
# Epoch 451 | Train Sharpe: 0.1615 | Val Sharpe: 0.2071
# Epoch 452 | Train Sharpe: 0.1631 | Val Sharpe: 0.2088
# Epoch 453 | Train Sharpe: 0.1632 | Val Sharpe: 0.2081
# Epoch 454 | Train Sharpe: 0.1638 | Val Sharpe: 0.2082
# Epoch 455 | Train Sharpe: 0.1643 | Val Sharpe: 0.2081
# Epoch 456 | Train Sharpe: 0.1645 | Val Sharpe: 0.2080
# Epoch 457 | Train Sharpe: 0.1643 | Val Sharpe: 0.2077
# Epoch 458 | Train Sharpe: 0.1619 | Val Sharpe: 0.2071
# Epoch 459 | Train Sharpe: 0.1631 | Val Sharpe: 0.2089
# Epoch 460 | Train Sharpe: 0.1632 | Val Sharpe: 0.2081
# Epoch 461 | Train Sharpe: 0.1639 | Val Sharpe: 0.2083
# Epoch 462 | Train Sharpe: 0.1644 | Val Sharpe: 0.2082
# Epoch 463 | Train Sharpe: 0.1648 | Val Sharpe: 0.2081
# Epoch 464 | Train Sharpe: 0.1649 | Val Sharpe: 0.2079
# Epoch 465 | Train Sharpe: 0.1641 | Val Sharpe: 0.2075
# Epoch 466 | Train Sharpe: 0.1593 | Val Sharpe: 0.2066
# Epoch 467 | Train Sharpe: 0.1633 | Val Sharpe: 0.2077
# Epoch 468 | Train Sharpe: 0.1634 | Val Sharpe: 0.2072
# Epoch 469 | Train Sharpe: 0.1607 | Val Sharpe: 0.2069
# Epoch 470 | Train Sharpe: 0.1644 | Val Sharpe: 0.2083
# Epoch 471 | Train Sharpe: 0.1642 | Val Sharpe: 0.2076
# Epoch 472 | Train Sharpe: 0.1633 | Val Sharpe: 0.2074
# Epoch 473 | Train Sharpe: 0.1600 | Val Sharpe: 0.2067
# Epoch 474 | Train Sharpe: 0.1641 | Val Sharpe: 0.2080
# Epoch 475 | Train Sharpe: 0.1619 | Val Sharpe: 0.2070
# Epoch 476 | Train Sharpe: 0.1630 | Val Sharpe: 0.2088
# Epoch 477 | Train Sharpe: 0.1632 | Val Sharpe: 0.2080
# Epoch 478 | Train Sharpe: 0.1638 | Val Sharpe: 0.2082
# Epoch 479 | Train Sharpe: 0.1643 | Val Sharpe: 0.2081
# Epoch 480 | Train Sharpe: 0.1647 | Val Sharpe: 0.2080
# Epoch 481 | Train Sharpe: 0.1647 | Val Sharpe: 0.2078
# Epoch 482 | Train Sharpe: 0.1635 | Val Sharpe: 0.2073
# Epoch 483 | Train Sharpe: 0.1623 | Val Sharpe: 0.2071
# Epoch 484 | Train Sharpe: 0.1630 | Val Sharpe: 0.2087
# Epoch 485 | Train Sharpe: 0.1631 | Val Sharpe: 0.2081
# Epoch 486 | Train Sharpe: 0.1638 | Val Sharpe: 0.2082
# Epoch 487 | Train Sharpe: 0.1644 | Val Sharpe: 0.2082
# Epoch 488 | Train Sharpe: 0.1649 | Val Sharpe: 0.2081
# Epoch 489 | Train Sharpe: 0.1651 | Val Sharpe: 0.2080
# Epoch 490 | Train Sharpe: 0.1648 | Val Sharpe: 0.2078
# Epoch 491 | Train Sharpe: 0.1620 | Val Sharpe: 0.2073
# Epoch 492 | Train Sharpe: 0.1636 | Val Sharpe: 0.2090
# Epoch 493 | Train Sharpe: 0.1637 | Val Sharpe: 0.2082
# Epoch 494 | Train Sharpe: 0.1643 | Val Sharpe: 0.2083
# Epoch 495 | Train Sharpe: 0.1648 | Val Sharpe: 0.2082
# Epoch 496 | Train Sharpe: 0.1652 | Val Sharpe: 0.2081
# Epoch 497 | Train Sharpe: 0.1653 | Val Sharpe: 0.2079
# Epoch 498 | Train Sharpe: 0.1645 | Val Sharpe: 0.2076
# Epoch 499 | Train Sharpe: 0.1599 | Val Sharpe: 0.2066
# Epoch 500 | Train Sharpe: 0.1639 | Val Sharpe: 0.2077
# Epoch 501 | Train Sharpe: 0.1631 | Val Sharpe: 0.2071
# Epoch 502 | Train Sharpe: 0.1646 | Val Sharpe: 0.2083
# Epoch 503 | Train Sharpe: 0.1648 | Val Sharpe: 0.2078
# Epoch 504 | Train Sharpe: 0.1651 | Val Sharpe: 0.2079
# Epoch 505 | Train Sharpe: 0.1648 | Val Sharpe: 0.2077
# Epoch 506 | Train Sharpe: 0.1624 | Val Sharpe: 0.2071
# Epoch 507 | Train Sharpe: 0.1638 | Val Sharpe: 0.2088
# Epoch 508 | Train Sharpe: 0.1639 | Val Sharpe: 0.2081
# Epoch 509 | Train Sharpe: 0.1646 | Val Sharpe: 0.2082
# Epoch 510 | Train Sharpe: 0.1651 | Val Sharpe: 0.2081
# Epoch 511 | Train Sharpe: 0.1654 | Val Sharpe: 0.2080
# Epoch 512 | Train Sharpe: 0.1652 | Val Sharpe: 0.2078
# Epoch 513 | Train Sharpe: 0.1633 | Val Sharpe: 0.2072
# Epoch 514 | Train Sharpe: 0.1643 | Val Sharpe: 0.2087
# Epoch 515 | Train Sharpe: 0.1644 | Val Sharpe: 0.2081
# Epoch 516 | Train Sharpe: 0.1650 | Val Sharpe: 0.2082
# Epoch 517 | Train Sharpe: 0.1654 | Val Sharpe: 0.2081
# Epoch 518 | Train Sharpe: 0.1655 | Val Sharpe: 0.2080
# Epoch 519 | Train Sharpe: 0.1648 | Val Sharpe: 0.2076
# Epoch 520 | Train Sharpe: 0.1600 | Val Sharpe: 0.2067
# Epoch 521 | Train Sharpe: 0.1641 | Val Sharpe: 0.2078
# Epoch 522 | Train Sharpe: 0.1618 | Val Sharpe: 0.2069
# Epoch 523 | Train Sharpe: 0.1646 | Val Sharpe: 0.2087
# Epoch 524 | Train Sharpe: 0.1647 | Val Sharpe: 0.2079
# Epoch 525 | Train Sharpe: 0.1651 | Val Sharpe: 0.2080
# Epoch 526 | Train Sharpe: 0.1650 | Val Sharpe: 0.2077
# Epoch 527 | Train Sharpe: 0.1631 | Val Sharpe: 0.2072
# Epoch 528 | Train Sharpe: 0.1641 | Val Sharpe: 0.2087
# Epoch 529 | Train Sharpe: 0.1643 | Val Sharpe: 0.2081
# Epoch 530 | Train Sharpe: 0.1649 | Val Sharpe: 0.2082
# Epoch 531 | Train Sharpe: 0.1653 | Val Sharpe: 0.2081
# Epoch 532 | Train Sharpe: 0.1655 | Val Sharpe: 0.2080
# Epoch 533 | Train Sharpe: 0.1651 | Val Sharpe: 0.2077
# Epoch 534 | Train Sharpe: 0.1616 | Val Sharpe: 0.2069
# Epoch 535 | Train Sharpe: 0.1654 | Val Sharpe: 0.2084
# Epoch 536 | Train Sharpe: 0.1648 | Val Sharpe: 0.2076
# Epoch 537 | Train Sharpe: 0.1620 | Val Sharpe: 0.2074
# Epoch 538 | Train Sharpe: 0.1647 | Val Sharpe: 0.2089
# Epoch 539 | Train Sharpe: 0.1648 | Val Sharpe: 0.2082
# Epoch 540 | Train Sharpe: 0.1653 | Val Sharpe: 0.2082
# Epoch 541 | Train Sharpe: 0.1654 | Val Sharpe: 0.2081
# Epoch 542 | Train Sharpe: 0.1646 | Val Sharpe: 0.2077
# Epoch 543 | Train Sharpe: 0.1604 | Val Sharpe: 0.2069
# Epoch 544 | Train Sharpe: 0.1644 | Val Sharpe: 0.2080
# Epoch 545 | Train Sharpe: 0.1602 | Val Sharpe: 0.2070
# Epoch 546 | Train Sharpe: 0.1646 | Val Sharpe: 0.2083
# Epoch 547 | Train Sharpe: 0.1613 | Val Sharpe: 0.2069
# Epoch 548 | Train Sharpe: 0.1651 | Val Sharpe: 0.2085
# Epoch 549 | Train Sharpe: 0.1647 | Val Sharpe: 0.2078
# Epoch 550 | Train Sharpe: 0.1629 | Val Sharpe: 0.2074
# Epoch 551 | Train Sharpe: 0.1642 | Val Sharpe: 0.2089
# Epoch 552 | Train Sharpe: 0.1643 | Val Sharpe: 0.2083
# Epoch 553 | Train Sharpe: 0.1649 | Val Sharpe: 0.2084
# Epoch 554 | Train Sharpe: 0.1654 | Val Sharpe: 0.2083
# Epoch 555 | Train Sharpe: 0.1655 | Val Sharpe: 0.2082
# Epoch 556 | Train Sharpe: 0.1649 | Val Sharpe: 0.2079
# Epoch 557 | Train Sharpe: 0.1609 | Val Sharpe: 0.2072
# Epoch 558 | Train Sharpe: 0.1650 | Val Sharpe: 0.2083
# Epoch 559 | Train Sharpe: 0.1616 | Val Sharpe: 0.2073
# Epoch 560 | Train Sharpe: 0.1653 | Val Sharpe: 0.2089
# Epoch 561 | Train Sharpe: 0.1652 | Val Sharpe: 0.2081
# Epoch 562 | Train Sharpe: 0.1648 | Val Sharpe: 0.2080
# Epoch 563 | Train Sharpe: 0.1615 | Val Sharpe: 0.2072
# Epoch 564 | Train Sharpe: 0.1653 | Val Sharpe: 0.2085
# Epoch 565 | Train Sharpe: 0.1644 | Val Sharpe: 0.2077
# Epoch 566 | Train Sharpe: 0.1608 | Val Sharpe: 0.2072
# Epoch 567 | Train Sharpe: 0.1648 | Val Sharpe: 0.2083
# Epoch 568 | Train Sharpe: 0.1611 | Val Sharpe: 0.2072
# Epoch 569 | Train Sharpe: 0.1652 | Val Sharpe: 0.2087
# Epoch 570 | Train Sharpe: 0.1644 | Val Sharpe: 0.2078
# Epoch 571 | Train Sharpe: 0.1608 | Val Sharpe: 0.2072
# Epoch 572 | Train Sharpe: 0.1647 | Val Sharpe: 0.2084
# Epoch 573 | Train Sharpe: 0.1612 | Val Sharpe: 0.2073
# Epoch 574 | Train Sharpe: 0.1652 | Val Sharpe: 0.2089
# Epoch 575 | Train Sharpe: 0.1647 | Val Sharpe: 0.2079
# Epoch 576 | Train Sharpe: 0.1624 | Val Sharpe: 0.2075
# Epoch 577 | Train Sharpe: 0.1648 | Val Sharpe: 0.2088
# Epoch 578 | Train Sharpe: 0.1650 | Val Sharpe: 0.2082
# Epoch 579 | Train Sharpe: 0.1655 | Val Sharpe: 0.2083
# Epoch 580 | Train Sharpe: 0.1654 | Val Sharpe: 0.2082
# Epoch 581 | Train Sharpe: 0.1640 | Val Sharpe: 0.2078
# Epoch 582 | Train Sharpe: 0.1656 | Val Sharpe: 0.2088
# Epoch 583 | Train Sharpe: 0.1657 | Val Sharpe: 0.2083
# Epoch 584 | Train Sharpe: 0.1655 | Val Sharpe: 0.2082
# Epoch 585 | Train Sharpe: 0.1627 | Val Sharpe: 0.2076
# Epoch 586 | Train Sharpe: 0.1655 | Val Sharpe: 0.2090
# Epoch 587 | Train Sharpe: 0.1656 | Val Sharpe: 0.2084
# Epoch 588 | Train Sharpe: 0.1658 | Val Sharpe: 0.2085
# Epoch 589 | Train Sharpe: 0.1651 | Val Sharpe: 0.2081
# Epoch 590 | Train Sharpe: 0.1617 | Val Sharpe: 0.2075
# Epoch 591 | Train Sharpe: 0.1656 | Val Sharpe: 0.2086
# Epoch 592 | Train Sharpe: 0.1629 | Val Sharpe: 0.2078
# Epoch 593 | Train Sharpe: 0.1651 | Val Sharpe: 0.2094
# Epoch 594 | Train Sharpe: 0.1653 | Val Sharpe: 0.2087
# Epoch 595 | Train Sharpe: 0.1658 | Val Sharpe: 0.2087
# Epoch 596 | Train Sharpe: 0.1661 | Val Sharpe: 0.2086
# Epoch 597 | Train Sharpe: 0.1658 | Val Sharpe: 0.2083
# Epoch 598 | Train Sharpe: 0.1628 | Val Sharpe: 0.2077
# Epoch 599 | Train Sharpe: 0.1661 | Val Sharpe: 0.2090
# Epoch 600 | Train Sharpe: 0.1659 | Val Sharpe: 0.2084
# Epoch 601 | Train Sharpe: 0.1650 | Val Sharpe: 0.2084
# Epoch 602 | Train Sharpe: 0.1631 | Val Sharpe: 0.2080
# Epoch 603 | Train Sharpe: 0.1658 | Val Sharpe: 0.2093
# Epoch 604 | Train Sharpe: 0.1659 | Val Sharpe: 0.2087
# Epoch 605 | Train Sharpe: 0.1661 | Val Sharpe: 0.2088
# Epoch 606 | Train Sharpe: 0.1658 | Val Sharpe: 0.2085
# Epoch 607 | Train Sharpe: 0.1627 | Val Sharpe: 0.2078
# Epoch 608 | Train Sharpe: 0.1663 | Val Sharpe: 0.2091
# Epoch 609 | Train Sharpe: 0.1658 | Val Sharpe: 0.2084
# Epoch 610 | Train Sharpe: 0.1640 | Val Sharpe: 0.2081
# Epoch 611 | Train Sharpe: 0.1654 | Val Sharpe: 0.2094
# Epoch 612 | Train Sharpe: 0.1656 | Val Sharpe: 0.2088
# Epoch 613 | Train Sharpe: 0.1662 | Val Sharpe: 0.2090
# Epoch 614 | Train Sharpe: 0.1665 | Val Sharpe: 0.2089
# Epoch 615 | Train Sharpe: 0.1665 | Val Sharpe: 0.2089
# Epoch 616 | Train Sharpe: 0.1654 | Val Sharpe: 0.2085
# Epoch 617 | Train Sharpe: 0.1644 | Val Sharpe: 0.2083
# Epoch 618 | Train Sharpe: 0.1656 | Val Sharpe: 0.2095
# Epoch 619 | Train Sharpe: 0.1657 | Val Sharpe: 0.2090
# Epoch 620 | Train Sharpe: 0.1663 | Val Sharpe: 0.2091
# Epoch 621 | Train Sharpe: 0.1667 | Val Sharpe: 0.2091
# Epoch 622 | Train Sharpe: 0.1668 | Val Sharpe: 0.2091
# Epoch 623 | Train Sharpe: 0.1662 | Val Sharpe: 0.2088
# Epoch 624 | Train Sharpe: 0.1624 | Val Sharpe: 0.2080
# Epoch 625 | Train Sharpe: 0.1664 | Val Sharpe: 0.2091
# Epoch 626 | Train Sharpe: 0.1634 | Val Sharpe: 0.2083
# Epoch 627 | Train Sharpe: 0.1661 | Val Sharpe: 0.2098
# Epoch 628 | Train Sharpe: 0.1663 | Val Sharpe: 0.2091
# Epoch 629 | Train Sharpe: 0.1666 | Val Sharpe: 0.2092
# Epoch 630 | Train Sharpe: 0.1666 | Val Sharpe: 0.2090
# Epoch 631 | Train Sharpe: 0.1648 | Val Sharpe: 0.2085
# Epoch 632 | Train Sharpe: 0.1663 | Val Sharpe: 0.2096
# Epoch 633 | Train Sharpe: 0.1665 | Val Sharpe: 0.2091
# Epoch 634 | Train Sharpe: 0.1669 | Val Sharpe: 0.2092
# Epoch 635 | Train Sharpe: 0.1669 | Val Sharpe: 0.2092
# Epoch 636 | Train Sharpe: 0.1661 | Val Sharpe: 0.2089
# Epoch 637 | Train Sharpe: 0.1627 | Val Sharpe: 0.2082
# Epoch 638 | Train Sharpe: 0.1667 | Val Sharpe: 0.2092
# Epoch 639 | Train Sharpe: 0.1641 | Val Sharpe: 0.2085
# Epoch 640 | Train Sharpe: 0.1658 | Val Sharpe: 0.2101
# Epoch 641 | Train Sharpe: 0.1660 | Val Sharpe: 0.2094
# Epoch 642 | Train Sharpe: 0.1666 | Val Sharpe: 0.2096
# Epoch 643 | Train Sharpe: 0.1670 | Val Sharpe: 0.2095
# Epoch 644 | Train Sharpe: 0.1671 | Val Sharpe: 0.2093
# Epoch 645 | Train Sharpe: 0.1663 | Val Sharpe: 0.2090
# Epoch 646 | Train Sharpe: 0.1628 | Val Sharpe: 0.2084
# Epoch 647 | Train Sharpe: 0.1668 | Val Sharpe: 0.2094
# Epoch 648 | Train Sharpe: 0.1638 | Val Sharpe: 0.2086
# Epoch 649 | Train Sharpe: 0.1664 | Val Sharpe: 0.2102
# Epoch 650 | Train Sharpe: 0.1666 | Val Sharpe: 0.2095
# Epoch 651 | Train Sharpe: 0.1670 | Val Sharpe: 0.2096
# Epoch 652 | Train Sharpe: 0.1671 | Val Sharpe: 0.2094
# Epoch 653 | Train Sharpe: 0.1660 | Val Sharpe: 0.2090
# Epoch 654 | Train Sharpe: 0.1653 | Val Sharpe: 0.2089
# Epoch 655 | Train Sharpe: 0.1665 | Val Sharpe: 0.2099
# Epoch 656 | Train Sharpe: 0.1667 | Val Sharpe: 0.2095
# Epoch 657 | Train Sharpe: 0.1672 | Val Sharpe: 0.2097
# Epoch 658 | Train Sharpe: 0.1675 | Val Sharpe: 0.2096
# Epoch 659 | Train Sharpe: 0.1672 | Val Sharpe: 0.2094
# Epoch 660 | Train Sharpe: 0.1643 | Val Sharpe: 0.2088
# Epoch 661 | Train Sharpe: 0.1669 | Val Sharpe: 0.2101
# Epoch 662 | Train Sharpe: 0.1670 | Val Sharpe: 0.2095
# Epoch 663 | Train Sharpe: 0.1671 | Val Sharpe: 0.2097
# Epoch 664 | Train Sharpe: 0.1655 | Val Sharpe: 0.2096
# Epoch 665 | Train Sharpe: 0.1649 | Val Sharpe: 0.2095
# Epoch 666 | Train Sharpe: 0.1667 | Val Sharpe: 0.2102
# Epoch 667 | Train Sharpe: 0.1669 | Val Sharpe: 0.2098
# Epoch 668 | Train Sharpe: 0.1673 | Val Sharpe: 0.2099
# Epoch 669 | Train Sharpe: 0.1673 | Val Sharpe: 0.2098
# Epoch 670 | Train Sharpe: 0.1662 | Val Sharpe: 0.2097
# Epoch 671 | Train Sharpe: 0.1626 | Val Sharpe: 0.2092
# Epoch 672 | Train Sharpe: 0.1668 | Val Sharpe: 0.2101
# Epoch 673 | Train Sharpe: 0.1645 | Val Sharpe: 0.2094
# Epoch 674 | Train Sharpe: 0.1663 | Val Sharpe: 0.2107
# Epoch 675 | Train Sharpe: 0.1666 | Val Sharpe: 0.2100
# Epoch 676 | Train Sharpe: 0.1673 | Val Sharpe: 0.2101
# Epoch 677 | Train Sharpe: 0.1676 | Val Sharpe: 0.2101
# Epoch 678 | Train Sharpe: 0.1674 | Val Sharpe: 0.2099
# Epoch 679 | Train Sharpe: 0.1654 | Val Sharpe: 0.2095
# Epoch 680 | Train Sharpe: 0.1667 | Val Sharpe: 0.2105
# Epoch 681 | Train Sharpe: 0.1671 | Val Sharpe: 0.2100
# Epoch 682 | Train Sharpe: 0.1677 | Val Sharpe: 0.2102
# Epoch 683 | Train Sharpe: 0.1680 | Val Sharpe: 0.2102
# Epoch 684 | Train Sharpe: 0.1679 | Val Sharpe: 0.2100
# Epoch 685 | Train Sharpe: 0.1656 | Val Sharpe: 0.2099
# Epoch 686 | Train Sharpe: 0.1669 | Val Sharpe: 0.2110
# Epoch 687 | Train Sharpe: 0.1672 | Val Sharpe: 0.2104
# Epoch 688 | Train Sharpe: 0.1678 | Val Sharpe: 0.2106
# Epoch 689 | Train Sharpe: 0.1682 | Val Sharpe: 0.2104
# Epoch 690 | Train Sharpe: 0.1682 | Val Sharpe: 0.2104
# Epoch 691 | Train Sharpe: 0.1670 | Val Sharpe: 0.2100
# Epoch 692 | Train Sharpe: 0.1658 | Val Sharpe: 0.2097
# Epoch 693 | Train Sharpe: 0.1667 | Val Sharpe: 0.2108
# Epoch 694 | Train Sharpe: 0.1671 | Val Sharpe: 0.2103
# Epoch 695 | Train Sharpe: 0.1678 | Val Sharpe: 0.2106
# Epoch 696 | Train Sharpe: 0.1684 | Val Sharpe: 0.2106
# Epoch 697 | Train Sharpe: 0.1687 | Val Sharpe: 0.2107
# Epoch 698 | Train Sharpe: 0.1686 | Val Sharpe: 0.2105
# Epoch 699 | Train Sharpe: 0.1663 | Val Sharpe: 0.2104
# Epoch 700 | Train Sharpe: 0.1675 | Val Sharpe: 0.2114
# Epoch 701 | Train Sharpe: 0.1678 | Val Sharpe: 0.2108
# Epoch 702 | Train Sharpe: 0.1685 | Val Sharpe: 0.2110
# Epoch 703 | Train Sharpe: 0.1689 | Val Sharpe: 0.2108
# Epoch 704 | Train Sharpe: 0.1688 | Val Sharpe: 0.2109
# Epoch 705 | Train Sharpe: 0.1675 | Val Sharpe: 0.2105
# Epoch 706 | Train Sharpe: 0.1680 | Val Sharpe: 0.2104
# Epoch 707 | Train Sharpe: 0.1638 | Val Sharpe: 0.2101
# Epoch 708 | Train Sharpe: 0.1683 | Val Sharpe: 0.2112
# Epoch 709 | Train Sharpe: 0.1662 | Val Sharpe: 0.2100
# Epoch 710 | Train Sharpe: 0.1673 | Val Sharpe: 0.2113
# Epoch 711 | Train Sharpe: 0.1677 | Val Sharpe: 0.2107
# Epoch 712 | Train Sharpe: 0.1686 | Val Sharpe: 0.2110
# Epoch 713 | Train Sharpe: 0.1691 | Val Sharpe: 0.2110
# Epoch 714 | Train Sharpe: 0.1693 | Val Sharpe: 0.2111
# Epoch 715 | Train Sharpe: 0.1688 | Val Sharpe: 0.2109
# Epoch 716 | Train Sharpe: 0.1644 | Val Sharpe: 0.2101
# Epoch 717 | Train Sharpe: 0.1688 | Val Sharpe: 0.2109
# Epoch 718 | Train Sharpe: 0.1651 | Val Sharpe: 0.2103
# Epoch 719 | Train Sharpe: 0.1690 | Val Sharpe: 0.2117
# Epoch 720 | Train Sharpe: 0.1690 | Val Sharpe: 0.2110
# Epoch 721 | Train Sharpe: 0.1686 | Val Sharpe: 0.2110
# Epoch 722 | Train Sharpe: 0.1642 | Val Sharpe: 0.2102
# Epoch 723 | Train Sharpe: 0.1686 | Val Sharpe: 0.2111
# Epoch 724 | Train Sharpe: 0.1636 | Val Sharpe: 0.2104
# Epoch 725 | Train Sharpe: 0.1684 | Val Sharpe: 0.2116
# Epoch 726 | Train Sharpe: 0.1644 | Val Sharpe: 0.2102
# Epoch 727 | Train Sharpe: 0.1689 | Val Sharpe: 0.2113
# Epoch 728 | Train Sharpe: 0.1659 | Val Sharpe: 0.2107
# Epoch 729 | Train Sharpe: 0.1685 | Val Sharpe: 0.2121
# Epoch 730 | Train Sharpe: 0.1689 | Val Sharpe: 0.2114
# Epoch 731 | Train Sharpe: 0.1697 | Val Sharpe: 0.2115
# Epoch 732 | Train Sharpe: 0.1699 | Val Sharpe: 0.2114
# Epoch 733 | Train Sharpe: 0.1692 | Val Sharpe: 0.2111
# Epoch 734 | Train Sharpe: 0.1654 | Val Sharpe: 0.2105
# Epoch 735 | Train Sharpe: 0.1697 | Val Sharpe: 0.2114
# Epoch 736 | Train Sharpe: 0.1665 | Val Sharpe: 0.2109
# Epoch 737 | Train Sharpe: 0.1695 | Val Sharpe: 0.2123
# Epoch 738 | Train Sharpe: 0.1699 | Val Sharpe: 0.2116
# Epoch 739 | Train Sharpe: 0.1703 | Val Sharpe: 0.2117
# Epoch 740 | Train Sharpe: 0.1697 | Val Sharpe: 0.2114
# Epoch 741 | Train Sharpe: 0.1656 | Val Sharpe: 0.2108
# Epoch 742 | Train Sharpe: 0.1700 | Val Sharpe: 0.2116
# Epoch 743 | Train Sharpe: 0.1657 | Val Sharpe: 0.2111
# Epoch 744 | Train Sharpe: 0.1702 | Val Sharpe: 0.2123
# Epoch 745 | Train Sharpe: 0.1682 | Val Sharpe: 0.2116
# Epoch 746 | Train Sharpe: 0.1704 | Val Sharpe: 0.2125
# Epoch 747 | Train Sharpe: 0.1706 | Val Sharpe: 0.2119
# Epoch 748 | Train Sharpe: 0.1704 | Val Sharpe: 0.2118
# Epoch 749 | Train Sharpe: 0.1668 | Val Sharpe: 0.2111
# Epoch 750 | Train Sharpe: 0.1709 | Val Sharpe: 0.2121
# Epoch 751 | Train Sharpe: 0.1701 | Val Sharpe: 0.2117
# Epoch 752 | Train Sharpe: 0.1662 | Val Sharpe: 0.2113
# Epoch 753 | Train Sharpe: 0.1706 | Val Sharpe: 0.2120
# Epoch 754 | Train Sharpe: 0.1668 | Val Sharpe: 0.2115
# Epoch 755 | Train Sharpe: 0.1710 | Val Sharpe: 0.2128
# Epoch 756 | Train Sharpe: 0.1706 | Val Sharpe: 0.2121
# Epoch 757 | Train Sharpe: 0.1680 | Val Sharpe: 0.2118
# Epoch 758 | Train Sharpe: 0.1709 | Val Sharpe: 0.2127
# Epoch 759 | Train Sharpe: 0.1713 | Val Sharpe: 0.2122
# Epoch 760 | Train Sharpe: 0.1715 | Val Sharpe: 0.2126
# Epoch 761 | Train Sharpe: 0.1703 | Val Sharpe: 0.2122
# Epoch 762 | Train Sharpe: 0.1712 | Val Sharpe: 0.2122
# Epoch 763 | Train Sharpe: 0.1664 | Val Sharpe: 0.2121
# Epoch 764 | Train Sharpe: 0.1712 | Val Sharpe: 0.2131
# Epoch 765 | Train Sharpe: 0.1679 | Val Sharpe: 0.2119
# Epoch 766 | Train Sharpe: 0.1717 | Val Sharpe: 0.2130
# Epoch 767 | Train Sharpe: 0.1718 | Val Sharpe: 0.2125
# Epoch 768 | Train Sharpe: 0.1708 | Val Sharpe: 0.2124
# Epoch 769 | Train Sharpe: 0.1720 | Val Sharpe: 0.2124
# Epoch 770 | Train Sharpe: 0.1673 | Val Sharpe: 0.2124
# Epoch 771 | Train Sharpe: 0.1720 | Val Sharpe: 0.2135
# Epoch 772 | Train Sharpe: 0.1703 | Val Sharpe: 0.2123
# Epoch 773 | Train Sharpe: 0.1722 | Val Sharpe: 0.2131
# Epoch 774 | Train Sharpe: 0.1727 | Val Sharpe: 0.2128
# Epoch 775 | Train Sharpe: 0.1729 | Val Sharpe: 0.2129
# Epoch 776 | Train Sharpe: 0.1714 | Val Sharpe: 0.2125
# Epoch 777 | Train Sharpe: 0.1731 | Val Sharpe: 0.2131
# Epoch 778 | Train Sharpe: 0.1734 | Val Sharpe: 0.2129
# Epoch 779 | Train Sharpe: 0.1730 | Val Sharpe: 0.2133
# Epoch 780 | Train Sharpe: 0.1692 | Val Sharpe: 0.2127
# Epoch 781 | Train Sharpe: 0.1735 | Val Sharpe: 0.2134
# Epoch 782 | Train Sharpe: 0.1729 | Val Sharpe: 0.2131
# Epoch 783 | Train Sharpe: 0.1691 | Val Sharpe: 0.2128
# Epoch 784 | Train Sharpe: 0.1736 | Val Sharpe: 0.2133
# Epoch 785 | Train Sharpe: 0.1697 | Val Sharpe: 0.2131
# Epoch 786 | Train Sharpe: 0.1738 | Val Sharpe: 0.2143
# Epoch 787 | Train Sharpe: 0.1737 | Val Sharpe: 0.2138
# Epoch 788 | Train Sharpe: 0.1719 | Val Sharpe: 0.2137
# Epoch 789 | Train Sharpe: 0.1731 | Val Sharpe: 0.2143
# Epoch 790 | Train Sharpe: 0.1737 | Val Sharpe: 0.2139
# Epoch 791 | Train Sharpe: 0.1745 | Val Sharpe: 0.2144
# Epoch 792 | Train Sharpe: 0.1750 | Val Sharpe: 0.2144
# Epoch 793 | Train Sharpe: 0.1749 | Val Sharpe: 0.2142
# Epoch 794 | Train Sharpe: 0.1704 | Val Sharpe: 0.2146
# Epoch 795 | Train Sharpe: 0.1751 | Val Sharpe: 0.2154
# Epoch 796 | Train Sharpe: 0.1749 | Val Sharpe: 0.2145
# Epoch 797 | Train Sharpe: 0.1717 | Val Sharpe: 0.2141
# Epoch 798 | Train Sharpe: 0.1759 | Val Sharpe: 0.2147
# Epoch 799 | Train Sharpe: 0.1756 | Val Sharpe: 0.2145
# Epoch 800 | Train Sharpe: 0.1730 | Val Sharpe: 0.2144
# Epoch 801 | Train Sharpe: 0.1761 | Val Sharpe: 0.2150
# Epoch 802 | Train Sharpe: 0.1766 | Val Sharpe: 0.2147
# Epoch 803 | Train Sharpe: 0.1766 | Val Sharpe: 0.2155
# Epoch 804 | Train Sharpe: 0.1744 | Val Sharpe: 0.2151
# Epoch 805 | Train Sharpe: 0.1757 | Val Sharpe: 0.2156
# Epoch 806 | Train Sharpe: 0.1768 | Val Sharpe: 0.2151
# Epoch 807 | Train Sharpe: 0.1776 | Val Sharpe: 0.2158
# Epoch 808 | Train Sharpe: 0.1781 | Val Sharpe: 0.2157
# Epoch 809 | Train Sharpe: 0.1781 | Val Sharpe: 0.2154
# Epoch 810 | Train Sharpe: 0.1739 | Val Sharpe: 0.2149
# Epoch 811 | Train Sharpe: 0.1781 | Val Sharpe: 0.2157
# Epoch 812 | Train Sharpe: 0.1765 | Val Sharpe: 0.2154
# Epoch 813 | Train Sharpe: 0.1765 | Val Sharpe: 0.2165
# Epoch 814 | Train Sharpe: 0.1778 | Val Sharpe: 0.2160
# Epoch 815 | Train Sharpe: 0.1789 | Val Sharpe: 0.2166
# Epoch 816 | Train Sharpe: 0.1798 | Val Sharpe: 0.2163
# Epoch 817 | Train Sharpe: 0.1798 | Val Sharpe: 0.2158
# Epoch 818 | Train Sharpe: 0.1759 | Val Sharpe: 0.2150
# Epoch 819 | Train Sharpe: 0.1806 | Val Sharpe: 0.2157
# Epoch 820 | Train Sharpe: 0.1779 | Val Sharpe: 0.2155
# Epoch 821 | Train Sharpe: 0.1787 | Val Sharpe: 0.2167
# Epoch 822 | Train Sharpe: 0.1800 | Val Sharpe: 0.2161
# Epoch 823 | Train Sharpe: 0.1813 | Val Sharpe: 0.2167
# Epoch 824 | Train Sharpe: 0.1823 | Val Sharpe: 0.2164
# Epoch 825 | Train Sharpe: 0.1823 | Val Sharpe: 0.2160
# Epoch 826 | Train Sharpe: 0.1783 | Val Sharpe: 0.2150
# Epoch 827 | Train Sharpe: 0.1834 | Val Sharpe: 0.2158
# Epoch 828 | Train Sharpe: 0.1806 | Val Sharpe: 0.2156
# Epoch 829 | Train Sharpe: 0.1817 | Val Sharpe: 0.2168
# Epoch 830 | Train Sharpe: 0.1831 | Val Sharpe: 0.2162
# Epoch 831 | Train Sharpe: 0.1846 | Val Sharpe: 0.2168
# Epoch 832 | Train Sharpe: 0.1855 | Val Sharpe: 0.2164
# Epoch 833 | Train Sharpe: 0.1847 | Val Sharpe: 0.2158
# Epoch 834 | Train Sharpe: 0.1865 | Val Sharpe: 0.2159
# Epoch 835 | Train Sharpe: 0.1854 | Val Sharpe: 0.2160
# Epoch 836 | Train Sharpe: 0.1874 | Val Sharpe: 0.2163
# Epoch 837 | Train Sharpe: 0.1870 | Val Sharpe: 0.2160
# Epoch 838 | Train Sharpe: 0.1834 | Val Sharpe: 0.2152
# Epoch 839 | Train Sharpe: 0.1884 | Val Sharpe: 0.2158
# Epoch 840 | Train Sharpe: 0.1882 | Val Sharpe: 0.2152
# Epoch 841 | Train Sharpe: 0.1831 | Val Sharpe: 0.2144
# Epoch 842 | Train Sharpe: 0.1892 | Val Sharpe: 0.2153
# Epoch 843 | Train Sharpe: 0.1855 | Val Sharpe: 0.2151
# Epoch 844 | Train Sharpe: 0.1871 | Val Sharpe: 0.2166
# Epoch 845 | Train Sharpe: 0.1874 | Val Sharpe: 0.2159
# Epoch 846 | Train Sharpe: 0.1888 | Val Sharpe: 0.2167
# Epoch 847 | Train Sharpe: 0.1895 | Val Sharpe: 0.2166
# Epoch 848 | Train Sharpe: 0.1888 | Val Sharpe: 0.2164
# Epoch 849 | Train Sharpe: 0.1857 | Val Sharpe: 0.2160
# Epoch 850 | Train Sharpe: 0.1887 | Val Sharpe: 0.2167
# Epoch 851 | Train Sharpe: 0.1891 | Val Sharpe: 0.2163
# Epoch 852 | Train Sharpe: 0.1900 | Val Sharpe: 0.2174
# Epoch 853 | Train Sharpe: 0.1873 | Val Sharpe: 0.2169
# Epoch 854 | Train Sharpe: 0.1867 | Val Sharpe: 0.2173
# Epoch 855 | Train Sharpe: 0.1872 | Val Sharpe: 0.2168
# Epoch 856 | Train Sharpe: 0.1889 | Val Sharpe: 0.2177
# Epoch 857 | Train Sharpe: 0.1899 | Val Sharpe: 0.2180
# Epoch 858 | Train Sharpe: 0.1903 | Val Sharpe: 0.2178
# Epoch 859 | Train Sharpe: 0.1873 | Val Sharpe: 0.2173
# Epoch 860 | Train Sharpe: 0.1876 | Val Sharpe: 0.2178
# Epoch 861 | Train Sharpe: 0.1881 | Val Sharpe: 0.2172
# Epoch 862 | Train Sharpe: 0.1898 | Val Sharpe: 0.2182
# Epoch 863 | Train Sharpe: 0.1905 | Val Sharpe: 0.2180
# Epoch 864 | Train Sharpe: 0.1900 | Val Sharpe: 0.2178
# Epoch 865 | Train Sharpe: 0.1855 | Val Sharpe: 0.2173
# Epoch 866 | Train Sharpe: 0.1908 | Val Sharpe: 0.2176
# Epoch 867 | Train Sharpe: 0.1898 | Val Sharpe: 0.2177
# Epoch 868 | Train Sharpe: 0.1866 | Val Sharpe: 0.2175
# Epoch 869 | Train Sharpe: 0.1899 | Val Sharpe: 0.2178
# Epoch 870 | Train Sharpe: 0.1904 | Val Sharpe: 0.2177
# Epoch 871 | Train Sharpe: 0.1905 | Val Sharpe: 0.2180
# Epoch 872 | Train Sharpe: 0.1850 | Val Sharpe: 0.2176
# Epoch 873 | Train Sharpe: 0.1911 | Val Sharpe: 0.2178
# Epoch 874 | Train Sharpe: 0.1865 | Val Sharpe: 0.2178
# Epoch 875 | Train Sharpe: 0.1902 | Val Sharpe: 0.2183
# Epoch 876 | Train Sharpe: 0.1906 | Val Sharpe: 0.2179
# Epoch 877 | Train Sharpe: 0.1909 | Val Sharpe: 0.2182
# Epoch 878 | Train Sharpe: 0.1859 | Val Sharpe: 0.2178
# Epoch 879 | Train Sharpe: 0.1913 | Val Sharpe: 0.2182
# Epoch 880 | Train Sharpe: 0.1897 | Val Sharpe: 0.2183
# Epoch 881 | Train Sharpe: 0.1912 | Val Sharpe: 0.2186
# Epoch 882 | Train Sharpe: 0.1876 | Val Sharpe: 0.2189
# Epoch 883 | Train Sharpe: 0.1895 | Val Sharpe: 0.2196
# Epoch 884 | Train Sharpe: 0.1898 | Val Sharpe: 0.2190
# Epoch 885 | Train Sharpe: 0.1911 | Val Sharpe: 0.2194
# Epoch 886 | Train Sharpe: 0.1914 | Val Sharpe: 0.2191
# Epoch 887 | Train Sharpe: 0.1881 | Val Sharpe: 0.2186
# ...
# Epoch 99715 | Train Sharpe: 0.6527 | Val Sharpe: 0.8719
# Epoch 99716 | Train Sharpe: 0.6105 | Val Sharpe: 0.8565
# Epoch 99717 | Train Sharpe: 0.6134 | Val Sharpe: 0.8198
# Epoch 99718 | Train Sharpe: 0.6665 | Val Sharpe: 0.8974
# Epoch 99719 | Train Sharpe: 0.6228 | Val Sharpe: 0.8639
# Epoch 99720 | Train Sharpe: 0.6460 | Val Sharpe: 0.9139
# Epoch 99721 | Train Sharpe: 0.6709 | Val Sharpe: 0.9086
# Epoch 99722 | Train Sharpe: 0.6000 | Val Sharpe: 0.8707
# Epoch 99723 | Train Sharpe: 0.5843 | Val Sharpe: 0.9090
# Epoch 99724 | Train Sharpe: 0.6285 | Val Sharpe: 0.8642
# Epoch 99725 | Train Sharpe: 0.6306 | Val Sharpe: 0.9077
# Epoch 99726 | Train Sharpe: 0.5959 | Val Sharpe: 0.7953
# Epoch 99727 | Train Sharpe: 0.6695 | Val Sharpe: 0.9098
# Epoch 99728 | Train Sharpe: 0.6248 | Val Sharpe: 0.8055
# Epoch 99729 | Train Sharpe: 0.6187 | Val Sharpe: 0.9027
# Epoch 99730 | Train Sharpe: 0.5830 | Val Sharpe: 0.8082
# Epoch 99731 | Train Sharpe: 0.6313 | Val Sharpe: 0.8974
# Epoch 99732 | Train Sharpe: 0.6298 | Val Sharpe: 0.8177
# Epoch 99733 | Train Sharpe: 0.6425 | Val Sharpe: 0.9083
# Epoch 99734 | Train Sharpe: 0.6043 | Val Sharpe: 0.8663
# Epoch 99735 | Train Sharpe: 0.6337 | Val Sharpe: 0.8803
# Epoch 99736 | Train Sharpe: 0.6357 | Val Sharpe: 0.8523
# Epoch 99737 | Train Sharpe: 0.6260 | Val Sharpe: 0.8846
# Epoch 99738 | Train Sharpe: 0.6244 | Val Sharpe: 0.8285
# Epoch 99739 | Train Sharpe: 0.6492 | Val Sharpe: 0.9120
# Epoch 99740 | Train Sharpe: 0.6834 | Val Sharpe: 0.8839
# Epoch 99741 | Train Sharpe: 0.6912 | Val Sharpe: 0.9102
# Epoch 99742 | Train Sharpe: 0.6280 | Val Sharpe: 0.8977
# Epoch 99743 | Train Sharpe: 0.6358 | Val Sharpe: 0.9093
# Epoch 99744 | Train Sharpe: 0.6577 | Val Sharpe: 0.8684
# Epoch 99745 | Train Sharpe: 0.6715 | Val Sharpe: 0.9055
# Epoch 99746 | Train Sharpe: 0.5916 | Val Sharpe: 0.8481
# Epoch 99747 | Train Sharpe: 0.5967 | Val Sharpe: 0.8738
# Epoch 99748 | Train Sharpe: 0.6123 | Val Sharpe: 0.8578
# Epoch 99749 | Train Sharpe: 0.6174 | Val Sharpe: 0.9136
# Epoch 99750 | Train Sharpe: 0.5911 | Val Sharpe: 0.8465
# Epoch 99751 | Train Sharpe: 0.6333 | Val Sharpe: 0.8921
# Epoch 99752 | Train Sharpe: 0.6629 | Val Sharpe: 0.9033
# Epoch 99753 | Train Sharpe: 0.5747 | Val Sharpe: 0.8413
# Epoch 99754 | Train Sharpe: 0.6018 | Val Sharpe: 0.9173
# Epoch 99755 | Train Sharpe: 0.6561 | Val Sharpe: 0.8640
# Epoch 99756 | Train Sharpe: 0.6464 | Val Sharpe: 0.9211
# Epoch 99757 | Train Sharpe: 0.6018 | Val Sharpe: 0.8142
# Epoch 99758 | Train Sharpe: 0.6476 | Val Sharpe: 0.9128
# Epoch 99759 | Train Sharpe: 0.6726 | Val Sharpe: 0.8860
# Epoch 99760 | Train Sharpe: 0.6143 | Val Sharpe: 0.9207
# Epoch 99761 | Train Sharpe: 0.6373 | Val Sharpe: 0.8635
# Epoch 99762 | Train Sharpe: 0.6455 | Val Sharpe: 0.8972
# Epoch 99763 | Train Sharpe: 0.6223 | Val Sharpe: 0.8818
# Epoch 99764 | Train Sharpe: 0.6387 | Val Sharpe: 0.8722
# Epoch 99765 | Train Sharpe: 0.6886 | Val Sharpe: 0.9184
# Epoch 99766 | Train Sharpe: 0.6442 | Val Sharpe: 0.8267
# Epoch 99767 | Train Sharpe: 0.6125 | Val Sharpe: 0.9093
# Epoch 99768 | Train Sharpe: 0.6382 | Val Sharpe: 0.8647
# Epoch 99769 | Train Sharpe: 0.6705 | Val Sharpe: 0.9032
# Epoch 99770 | Train Sharpe: 0.6454 | Val Sharpe: 0.8466
# Epoch 99771 | Train Sharpe: 0.6046 | Val Sharpe: 0.8887
# Epoch 99772 | Train Sharpe: 0.6678 | Val Sharpe: 0.8927
# Epoch 99773 | Train Sharpe: 0.6311 | Val Sharpe: 0.8752
# Epoch 99774 | Train Sharpe: 0.6969 | Val Sharpe: 0.9276
# Epoch 99775 | Train Sharpe: 0.6083 | Val Sharpe: 0.8311
# Epoch 99776 | Train Sharpe: 0.6325 | Val Sharpe: 0.9075
# Epoch 99777 | Train Sharpe: 0.6505 | Val Sharpe: 0.8484
# Epoch 99778 | Train Sharpe: 0.6178 | Val Sharpe: 0.9001
# Epoch 99779 | Train Sharpe: 0.6619 | Val Sharpe: 0.8620
# Epoch 99780 | Train Sharpe: 0.6518 | Val Sharpe: 0.8978
# Epoch 99781 | Train Sharpe: 0.6406 | Val Sharpe: 0.8852
# Epoch 99782 | Train Sharpe: 0.6370 | Val Sharpe: 0.8743
# Epoch 99783 | Train Sharpe: 0.6557 | Val Sharpe: 0.8950
# Epoch 99784 | Train Sharpe: 0.5461 | Val Sharpe: 0.7915
# Epoch 99785 | Train Sharpe: 0.6409 | Val Sharpe: 0.9070
# Epoch 99786 | Train Sharpe: 0.6181 | Val Sharpe: 0.8498
# Epoch 99787 | Train Sharpe: 0.6306 | Val Sharpe: 0.8853
# Epoch 99788 | Train Sharpe: 0.5703 | Val Sharpe: 0.7790
# Epoch 99789 | Train Sharpe: 0.6480 | Val Sharpe: 0.8863
# Epoch 99790 | Train Sharpe: 0.5617 | Val Sharpe: 0.7725
# Epoch 99791 | Train Sharpe: 0.6334 | Val Sharpe: 0.8930
# Epoch 99792 | Train Sharpe: 0.6331 | Val Sharpe: 0.7969
# Epoch 99793 | Train Sharpe: 0.6520 | Val Sharpe: 0.8988
# Epoch 99794 | Train Sharpe: 0.6365 | Val Sharpe: 0.8603
# Epoch 99795 | Train Sharpe: 0.6790 | Val Sharpe: 0.9079
# Epoch 99796 | Train Sharpe: 0.6738 | Val Sharpe: 0.8545
# Epoch 99797 | Train Sharpe: 0.6212 | Val Sharpe: 0.8956
# Epoch 99798 | Train Sharpe: 0.6486 | Val Sharpe: 0.8856
# Epoch 99799 | Train Sharpe: 0.6264 | Val Sharpe: 0.8732
# Epoch 99800 | Train Sharpe: 0.6601 | Val Sharpe: 0.8801
# Epoch 99801 | Train Sharpe: 0.5442 | Val Sharpe: 0.7875
# Epoch 99802 | Train Sharpe: 0.6396 | Val Sharpe: 0.8999
# Epoch 99803 | Train Sharpe: 0.6323 | Val Sharpe: 0.8382
# Epoch 99804 | Train Sharpe: 0.6414 | Val Sharpe: 0.9000
# Epoch 99805 | Train Sharpe: 0.6305 | Val Sharpe: 0.8356
# Epoch 99806 | Train Sharpe: 0.6417 | Val Sharpe: 0.8861
# Epoch 99807 | Train Sharpe: 0.5737 | Val Sharpe: 0.8472
# Epoch 99808 | Train Sharpe: 0.6514 | Val Sharpe: 0.8635
# Epoch 99809 | Train Sharpe: 0.5621 | Val Sharpe: 0.7645
# Epoch 99810 | Train Sharpe: 0.5704 | Val Sharpe: 0.8673
# Epoch 99811 | Train Sharpe: 0.5350 | Val Sharpe: 0.8463
# Epoch 99812 | Train Sharpe: 0.6371 | Val Sharpe: 0.8880
# Epoch 99813 | Train Sharpe: 0.6170 | Val Sharpe: 0.8533
# Epoch 99814 | Train Sharpe: 0.6604 | Val Sharpe: 0.8825
# Epoch 99815 | Train Sharpe: 0.6585 | Val Sharpe: 0.8584
# Epoch 99816 | Train Sharpe: 0.6765 | Val Sharpe: 0.8956
# Epoch 99817 | Train Sharpe: 0.6469 | Val Sharpe: 0.8403
# Epoch 99818 | Train Sharpe: 0.6453 | Val Sharpe: 0.8928
# Epoch 99819 | Train Sharpe: 0.6165 | Val Sharpe: 0.8383
# Epoch 99820 | Train Sharpe: 0.6382 | Val Sharpe: 0.8876
# Epoch 99821 | Train Sharpe: 0.6043 | Val Sharpe: 0.8219
# Epoch 99822 | Train Sharpe: 0.6349 | Val Sharpe: 0.8859
# Epoch 99823 | Train Sharpe: 0.6234 | Val Sharpe: 0.8555
# Epoch 99824 | Train Sharpe: 0.6630 | Val Sharpe: 0.8992
# Epoch 99825 | Train Sharpe: 0.6083 | Val Sharpe: 0.8260
# Epoch 99826 | Train Sharpe: 0.6436 | Val Sharpe: 0.8945
# Epoch 99827 | Train Sharpe: 0.6666 | Val Sharpe: 0.8936
# Epoch 99828 | Train Sharpe: 0.6590 | Val Sharpe: 0.8986
# Epoch 99829 | Train Sharpe: 0.5770 | Val Sharpe: 0.8126
# Epoch 99830 | Train Sharpe: 0.5279 | Val Sharpe: 0.8494
# Epoch 99831 | Train Sharpe: 0.6452 | Val Sharpe: 0.8614
# Epoch 99832 | Train Sharpe: 0.5737 | Val Sharpe: 0.8298
# Epoch 99833 | Train Sharpe: 0.6932 | Val Sharpe: 0.8949
# Epoch 99834 | Train Sharpe: 0.6426 | Val Sharpe: 0.8383
# Epoch 99835 | Train Sharpe: 0.6207 | Val Sharpe: 0.8776
# Epoch 99836 | Train Sharpe: 0.5363 | Val Sharpe: 0.8564
# Epoch 99837 | Train Sharpe: 0.6904 | Val Sharpe: 0.8861
# Epoch 99838 | Train Sharpe: 0.6259 | Val Sharpe: 0.8662
# Epoch 99839 | Train Sharpe: 0.6227 | Val Sharpe: 0.8876
# Epoch 99840 | Train Sharpe: 0.5994 | Val Sharpe: 0.8771
# Epoch 99841 | Train Sharpe: 0.6531 | Val Sharpe: 0.9079
# Epoch 99842 | Train Sharpe: 0.6325 | Val Sharpe: 0.8346
# Epoch 99843 | Train Sharpe: 0.6178 | Val Sharpe: 0.8779
# Epoch 99844 | Train Sharpe: 0.6350 | Val Sharpe: 0.8824
# Epoch 99845 | Train Sharpe: 0.6680 | Val Sharpe: 0.8705
# Epoch 99846 | Train Sharpe: 0.6743 | Val Sharpe: 0.8800
# Epoch 99847 | Train Sharpe: 0.6027 | Val Sharpe: 0.8582
# Epoch 99848 | Train Sharpe: 0.7074 | Val Sharpe: 0.9190
# Epoch 99849 | Train Sharpe: 0.6431 | Val Sharpe: 0.8506
# Epoch 99850 | Train Sharpe: 0.6060 | Val Sharpe: 0.8865
# Epoch 99851 | Train Sharpe: 0.5990 | Val Sharpe: 0.8113
# Epoch 99852 | Train Sharpe: 0.6499 | Val Sharpe: 0.8890
# Epoch 99853 | Train Sharpe: 0.6528 | Val Sharpe: 0.8840
# Epoch 99854 | Train Sharpe: 0.6464 | Val Sharpe: 0.8858
# Epoch 99855 | Train Sharpe: 0.6376 | Val Sharpe: 0.8730
# Epoch 99856 | Train Sharpe: 0.6219 | Val Sharpe: 0.8769
# Epoch 99857 | Train Sharpe: 0.6231 | Val Sharpe: 0.8360
# Epoch 99858 | Train Sharpe: 0.6672 | Val Sharpe: 0.8910
# Epoch 99859 | Train Sharpe: 0.6474 | Val Sharpe: 0.8596
# Epoch 99860 | Train Sharpe: 0.6627 | Val Sharpe: 0.8924
# Epoch 99861 | Train Sharpe: 0.6646 | Val Sharpe: 0.8588
# Epoch 99862 | Train Sharpe: 0.6526 | Val Sharpe: 0.8874
# Epoch 99863 | Train Sharpe: 0.5827 | Val Sharpe: 0.7992
# Epoch 99864 | Train Sharpe: 0.6569 | Val Sharpe: 0.8913
# Epoch 99865 | Train Sharpe: 0.5455 | Val Sharpe: 0.6938
# Epoch 99866 | Train Sharpe: 0.5994 | Val Sharpe: 0.8347
# Epoch 99867 | Train Sharpe: 0.6110 | Val Sharpe: 0.8597
# Epoch 99868 | Train Sharpe: 0.6409 | Val Sharpe: 0.8841
# Epoch 99869 | Train Sharpe: 0.6768 | Val Sharpe: 0.8949
# Epoch 99870 | Train Sharpe: 0.5869 | Val Sharpe: 0.8613
# Epoch 99871 | Train Sharpe: 0.6598 | Val Sharpe: 0.9124
# Epoch 99872 | Train Sharpe: 0.6575 | Val Sharpe: 0.8655
# Epoch 99873 | Train Sharpe: 0.6465 | Val Sharpe: 0.9102
# Epoch 99874 | Train Sharpe: 0.6381 | Val Sharpe: 0.8602
# Epoch 99875 | Train Sharpe: 0.6528 | Val Sharpe: 0.9003
# Epoch 99876 | Train Sharpe: 0.5453 | Val Sharpe: 0.7013
# Epoch 99877 | Train Sharpe: 0.6230 | Val Sharpe: 0.8306
# Epoch 99878 | Train Sharpe: 0.6750 | Val Sharpe: 0.8799
# Epoch 99879 | Train Sharpe: 0.6773 | Val Sharpe: 0.9084
# Epoch 99880 | Train Sharpe: 0.6490 | Val Sharpe: 0.9047
# Epoch 99881 | Train Sharpe: 0.5995 | Val Sharpe: 0.8625
# Epoch 99882 | Train Sharpe: 0.6649 | Val Sharpe: 0.8794
# Epoch 99883 | Train Sharpe: 0.6117 | Val Sharpe: 0.8715
# Epoch 99884 | Train Sharpe: 0.5870 | Val Sharpe: 0.8797
# Epoch 99885 | Train Sharpe: 0.6431 | Val Sharpe: 0.8825
# Epoch 99886 | Train Sharpe: 0.5484 | Val Sharpe: 0.8502
# Epoch 99887 | Train Sharpe: 0.6990 | Val Sharpe: 0.8883
# Epoch 99888 | Train Sharpe: 0.6495 | Val Sharpe: 0.8698
# Epoch 99889 | Train Sharpe: 0.6550 | Val Sharpe: 0.9093
# Epoch 99890 | Train Sharpe: 0.5790 | Val Sharpe: 0.8447
# Epoch 99891 | Train Sharpe: 0.6601 | Val Sharpe: 0.9038
# Epoch 99892 | Train Sharpe: 0.6066 | Val Sharpe: 0.8014
# Epoch 99893 | Train Sharpe: 0.6409 | Val Sharpe: 0.8948
# Epoch 99894 | Train Sharpe: 0.6193 | Val Sharpe: 0.8584
# Epoch 99895 | Train Sharpe: 0.6456 | Val Sharpe: 0.8908
# Epoch 99896 | Train Sharpe: 0.6292 | Val Sharpe: 0.8474
# Epoch 99897 | Train Sharpe: 0.6057 | Val Sharpe: 0.8773
# Epoch 99898 | Train Sharpe: 0.6138 | Val Sharpe: 0.8424
# Epoch 99899 | Train Sharpe: 0.6413 | Val Sharpe: 0.8839
# Epoch 99900 | Train Sharpe: 0.6017 | Val Sharpe: 0.8451
# Epoch 99901 | Train Sharpe: 0.6678 | Val Sharpe: 0.9016
# Epoch 99902 | Train Sharpe: 0.6422 | Val Sharpe: 0.8523
# Epoch 99903 | Train Sharpe: 0.6065 | Val Sharpe: 0.8829
# Epoch 99904 | Train Sharpe: 0.6131 | Val Sharpe: 0.8534
# Epoch 99905 | Train Sharpe: 0.6604 | Val Sharpe: 0.9014
# Epoch 99906 | Train Sharpe: 0.5362 | Val Sharpe: 0.7040
# Epoch 99907 | Train Sharpe: 0.5855 | Val Sharpe: 0.8710
# Epoch 99908 | Train Sharpe: 0.6399 | Val Sharpe: 0.8761
# Epoch 99909 | Train Sharpe: 0.6771 | Val Sharpe: 0.9037
# Epoch 99910 | Train Sharpe: 0.6550 | Val Sharpe: 0.9124
# Epoch 99911 | Train Sharpe: 0.6637 | Val Sharpe: 0.8868
# Epoch 99912 | Train Sharpe: 0.6704 | Val Sharpe: 0.8876
# Epoch 99913 | Train Sharpe: 0.6638 | Val Sharpe: 0.8796
# Epoch 99914 | Train Sharpe: 0.5883 | Val Sharpe: 0.8569
# Epoch 99915 | Train Sharpe: 0.6388 | Val Sharpe: 0.9149
# Epoch 99916 | Train Sharpe: 0.6260 | Val Sharpe: 0.8574
# Epoch 99917 | Train Sharpe: 0.6384 | Val Sharpe: 0.8874
# Epoch 99918 | Train Sharpe: 0.5735 | Val Sharpe: 0.8461
# Epoch 99919 | Train Sharpe: 0.5522 | Val Sharpe: 0.8854
# Epoch 99920 | Train Sharpe: 0.6322 | Val Sharpe: 0.8720
# Epoch 99921 | Train Sharpe: 0.6594 | Val Sharpe: 0.8947
# Epoch 99922 | Train Sharpe: 0.6076 | Val Sharpe: 0.8372
# Epoch 99923 | Train Sharpe: 0.6520 | Val Sharpe: 0.9052
# Epoch 99924 | Train Sharpe: 0.6905 | Val Sharpe: 0.8956
# Epoch 99925 | Train Sharpe: 0.6339 | Val Sharpe: 0.9042
# Epoch 99926 | Train Sharpe: 0.6279 | Val Sharpe: 0.8650
# Epoch 99927 | Train Sharpe: 0.6411 | Val Sharpe: 0.8893
# Epoch 99928 | Train Sharpe: 0.6510 | Val Sharpe: 0.8657
# Epoch 99929 | Train Sharpe: 0.5952 | Val Sharpe: 0.8748
# Epoch 99930 | Train Sharpe: 0.5907 | Val Sharpe: 0.8324
# Epoch 99931 | Train Sharpe: 0.6529 | Val Sharpe: 0.8986
# Epoch 99932 | Train Sharpe: 0.6589 | Val Sharpe: 0.8435
# Epoch 99933 | Train Sharpe: 0.6183 | Val Sharpe: 0.8916
# Epoch 99934 | Train Sharpe: 0.6177 | Val Sharpe: 0.8394
# Epoch 99935 | Train Sharpe: 0.6608 | Val Sharpe: 0.8983
# Epoch 99936 | Train Sharpe: 0.6539 | Val Sharpe: 0.8457
# Epoch 99937 | Train Sharpe: 0.6223 | Val Sharpe: 0.8903
# Epoch 99938 | Train Sharpe: 0.6261 | Val Sharpe: 0.8443
# Epoch 99939 | Train Sharpe: 0.6575 | Val Sharpe: 0.8966
# Epoch 99940 | Train Sharpe: 0.5931 | Val Sharpe: 0.8398
# Epoch 99941 | Train Sharpe: 0.6097 | Val Sharpe: 0.8926
# Epoch 99942 | Train Sharpe: 0.6374 | Val Sharpe: 0.8319
# Epoch 99943 | Train Sharpe: 0.6624 | Val Sharpe: 0.9016
# Epoch 99944 | Train Sharpe: 0.6632 | Val Sharpe: 0.8466
# Epoch 99945 | Train Sharpe: 0.6557 | Val Sharpe: 0.9028
# Epoch 99946 | Train Sharpe: 0.6669 | Val Sharpe: 0.8584
# Epoch 99947 | Train Sharpe: 0.6617 | Val Sharpe: 0.9053
# Epoch 99948 | Train Sharpe: 0.5807 | Val Sharpe: 0.8656
# Epoch 99949 | Train Sharpe: 0.5945 | Val Sharpe: 0.8927
# Epoch 99950 | Train Sharpe: 0.6494 | Val Sharpe: 0.8968
# Epoch 99951 | Train Sharpe: 0.6311 | Val Sharpe: 0.8638
# Epoch 99952 | Train Sharpe: 0.6369 | Val Sharpe: 0.9123
# Epoch 99953 | Train Sharpe: 0.5138 | Val Sharpe: 0.7132
# Epoch 99954 | Train Sharpe: 0.6639 | Val Sharpe: 0.8749
# Epoch 99955 | Train Sharpe: 0.6705 | Val Sharpe: 0.8730
# Epoch 99956 | Train Sharpe: 0.6144 | Val Sharpe: 0.8910
# Epoch 99957 | Train Sharpe: 0.6110 | Val Sharpe: 0.8576
# Epoch 99958 | Train Sharpe: 0.6517 | Val Sharpe: 0.8925
# Epoch 99959 | Train Sharpe: 0.6150 | Val Sharpe: 0.8221
# Epoch 99960 | Train Sharpe: 0.6569 | Val Sharpe: 0.9021
# Epoch 99961 | Train Sharpe: 0.6185 | Val Sharpe: 0.8580
# Epoch 99962 | Train Sharpe: 0.6006 | Val Sharpe: 0.8810
# Epoch 99963 | Train Sharpe: 0.6079 | Val Sharpe: 0.8563
# Epoch 99964 | Train Sharpe: 0.5972 | Val Sharpe: 0.8443
# Epoch 99965 | Train Sharpe: 0.6486 | Val Sharpe: 0.8878
# Epoch 99966 | Train Sharpe: 0.6733 | Val Sharpe: 0.8874
# Epoch 99967 | Train Sharpe: 0.5827 | Val Sharpe: 0.8620
# Epoch 99968 | Train Sharpe: 0.5496 | Val Sharpe: 0.8773
# Epoch 99969 | Train Sharpe: 0.6246 | Val Sharpe: 0.8517
# Epoch 99970 | Train Sharpe: 0.6538 | Val Sharpe: 0.8894
# Epoch 99971 | Train Sharpe: 0.6685 | Val Sharpe: 0.8843
# Epoch 99972 | Train Sharpe: 0.6168 | Val Sharpe: 0.8744
# Epoch 99973 | Train Sharpe: 0.6153 | Val Sharpe: 0.8650
# Epoch 99974 | Train Sharpe: 0.6283 | Val Sharpe: 0.8595
# Epoch 99975 | Train Sharpe: 0.6122 | Val Sharpe: 0.8586
# Epoch 99976 | Train Sharpe: 0.5892 | Val Sharpe: 0.8759
# Epoch 99977 | Train Sharpe: 0.6265 | Val Sharpe: 0.8923
# Epoch 99978 | Train Sharpe: 0.6709 | Val Sharpe: 0.8844
# Epoch 99979 | Train Sharpe: 0.6203 | Val Sharpe: 0.8381
# Epoch 99980 | Train Sharpe: 0.6695 | Val Sharpe: 0.9006
# Epoch 99981 | Train Sharpe: 0.6684 | Val Sharpe: 0.8688
# Epoch 99982 | Train Sharpe: 0.6434 | Val Sharpe: 0.8809
# Epoch 99983 | Train Sharpe: 0.6431 | Val Sharpe: 0.8565
# Epoch 99984 | Train Sharpe: 0.6664 | Val Sharpe: 0.8851
# Epoch 99985 | Train Sharpe: 0.6664 | Val Sharpe: 0.8618
# Epoch 99986 | Train Sharpe: 0.6186 | Val Sharpe: 0.8737
# Epoch 99987 | Train Sharpe: 0.6518 | Val Sharpe: 0.8912
# Epoch 99988 | Train Sharpe: 0.6541 | Val Sharpe: 0.8933
# Epoch 99989 | Train Sharpe: 0.6351 | Val Sharpe: 0.9054
# Epoch 99990 | Train Sharpe: 0.5851 | Val Sharpe: 0.8328
# Epoch 99991 | Train Sharpe: 0.6227 | Val Sharpe: 0.9035
# Epoch 99992 | Train Sharpe: 0.5961 | Val Sharpe: 0.8305
# Epoch 99993 | Train Sharpe: 0.6151 | Val Sharpe: 0.9027
# Epoch 99994 | Train Sharpe: 0.6513 | Val Sharpe: 0.8997
# Epoch 99995 | Train Sharpe: 0.6475 | Val Sharpe: 0.8939
# Epoch 99996 | Train Sharpe: 0.6006 | Val Sharpe: 0.8780
# Epoch 99997 | Train Sharpe: 0.6276 | Val Sharpe: 0.8785
# Epoch 99998 | Train Sharpe: 0.6457 | Val Sharpe: 0.8908
# Epoch 99999 | Train Sharpe: 0.5903 | Val Sharpe: 0.8446

# %% [markdown]
# Evaluate on the test set

# %%
test_sharpe, test_returns = trainer.test(test_data_tensor, test_returns_tensor)
print(f"Final Sharpe Ratio on Test Set: {test_sharpe:.4f}")
# Out:
# Final Sharpe Ratio on Test Set: 0.1496
